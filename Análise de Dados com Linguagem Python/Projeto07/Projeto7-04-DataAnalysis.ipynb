# %% [markdown]
# # <font color='blue'>Análise de Dados com Linguagem Python</font>
#
# ## <font color='blue'>Projeto 7</font>
# ## <font color='blue'>Web Data Analytics - Análise de Dados</font>

# %% [markdown]
# Responda as perguntas abaixo:
#
# - 1- Qual a média de score dos animes?
# - 2- Qual o anime com maior número de votos?
# - 3- Quais os tipos de animes?
# - 4- Qual a média de score por tipo de anime?
# - 5- Quais são as fontes dos animes?
# - 6- Quantos animes estão disponíveis em português?
# - 7- Quantos animes têm co-produtores (Co-Producer)?
# - 8- Há animes sem produtores?
# - 9- Quantos vezes cada produtor participou da produção de um anime?
# - 10- Considerando o produtor que mais participou da produção de animes, qual a média de score, popularidade e membros?

# %% [markdown]
# ## Instalando e Carregando os Pacotes

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.7

# %%
# Imports
import numpy as np
import pandas as pd

# %% [markdown]
# ## Carregando os Dados

# %%
df = pd.read_csv("dados/Processamento/animeData.csv")

# %%
df.head()
# Out:
#    ranking                                name  \
# 0        1    Fullmetal Alchemist: Brotherhood
# 1        2                            Gintama°
# 2        3  Shingeki no Kyojin Season 3 Part 2
# 3        4                         Steins;Gate
# 4        5            Fruits Basket: The Final
#
#                                            producers  votersCount  score  \
# 0  Aniplex;SquareEnix;MainichiBroadcastingSystem;...      1650275   9.15
# 1                             TVTokyo;Aniplex;Dentsu       173906   9.09
# 2  ProductionI.G;Dentsu;MainichiBroadcastingSyste...      1127900   9.09
# 3  FrontierWorks;MediaFactory;Movic;AT-X;Kadokawa...      1128557   9.09
# 4  TVTokyo;TVOsaka;NihonAdSystems;Hakusensha;Avex...       124091   9.06
#
#    popularity  members  favorite  episodes animeType  ... DialogueEditing  \
# 0           3  2713695    191501      64.0        TV  ...             NaN
# 1         337   493336     13063      51.0        TV  ...             NaN
# 2          33  1635976     46238      10.0        TV  ...             NaN
# 3          12  2117018    162324      24.0        TV  ...             NaN
# 4         619   288314     13330      13.0        TV  ...             NaN
#
#   RecordingEngineer Creator RecordingAssistant Publicity Co-Producer  \
# 0               NaN     NaN                NaN       NaN         NaN
# 1               NaN     NaN                NaN       NaN         NaN
# 2               NaN     NaN                NaN       NaN         NaN
# 3               NaN     NaN                NaN       NaN         NaN
# 4               NaN     NaN                NaN       NaN         NaN
#
#   CastingDirector Re-RecordingMixing AssistantProductionCoordinat  \
# 0             NaN                NaN                          NaN
# 1             NaN                NaN                          NaN
# 2             NaN                NaN                          NaN
# 3             NaN                NaN                          NaN
# 4             NaN                NaN                          NaN
#
#   SettingManager
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 90 columns]

# %%
pd.set_option("display.max_columns", 97)

# %%
df.head()
# Out:
#    ranking                                name  \
# 0        1    Fullmetal Alchemist: Brotherhood
# 1        2                            Gintama°
# 2        3  Shingeki no Kyojin Season 3 Part 2
# 3        4                         Steins;Gate
# 4        5            Fruits Basket: The Final
#
#                                            producers  votersCount  score  \
# 0  Aniplex;SquareEnix;MainichiBroadcastingSystem;...      1650275   9.15
# 1                             TVTokyo;Aniplex;Dentsu       173906   9.09
# 2  ProductionI.G;Dentsu;MainichiBroadcastingSyste...      1127900   9.09
# 3  FrontierWorks;MediaFactory;Movic;AT-X;Kadokawa...      1128557   9.09
# 4  TVTokyo;TVOsaka;NihonAdSystems;Hakusensha;Avex...       124091   9.06
#
#    popularity  members  favorite  episodes animeType premiredDate  \
# 0           3  2713695    191501      64.0        TV  Spring 2009
# 1         337   493336     13063      51.0        TV  Spring 2015
# 2          33  1635976     46238      10.0        TV  Spring 2019
# 3          12  2117018    162324      24.0        TV  Spring 2011
# 4         619   288314     13330      13.0        TV  Spring 2021
#
#     animeSource                                         genres  \
# 0         Manga          Action;Adventure;Comedy;Drama;Fantasy
# 1         Manga                           Action;Comedy;Sci-fi
# 2         Manga                   Action;Drama;Fantasy;Mystery
# 3  Visual novel                          Drama;Sci-fi;Suspense
# 4         Manga  Comedy;Drama;Romance;Sliceoflife;Supernatural
#
#                  studios                     licenses       rating  \
# 0                  Bones  Funimation;AniplexofAmerica        R-17+
# 1  Bandai Namco Pictures       Funimation;Crunchyroll  PG-13-Teens
# 2             Wit Studio                   Funimation        R-17+
# 3              White Fox                   Funimation  PG-13-Teens
# 4      TMS Entertainment                   Funimation  PG-13-Teens
#
#                                             Japanese  \
# 0  Kugimiya,Rie;Park,Romi;Utsumi,Kenji;Utsumi,Ken...
# 1  Kugimiya,Rie;Ishii,Kouji;Sugita,Tomokazu;Tomat...
# 2  Ishikawa,Yui;Inoue,Marina;Kamiya,Hiroshi;Kaji,...
# 3  Seki,Tomokazu;Imai,Asami;Miyano,Mamoru;Hanazaw...
# 4  Iwami,Manaka;Uchida,Yuuma;Shimazaki,Nobunaga;S...
#
#                                              Italian  \
# 0  Ponticelli,Benedetta;Novara,Renato;Scianca,Pat...
# 1                                                NaN
# 2  Perino,Elena;Bolognesi,Gaia;Raffaeli,Daniele;C...
# 3  Vivio,Paolo;Paolelli,Rachele;Chevalier,Davide;...
# 4                                                NaN
#
#                                       Portuguese(BR)  \
# 0  Andreatto,Rodrigo;Campos,Marcelo;Zink,Mariana;...
# 1                                                NaN
# 2  Stefane,Mayara;Volpato,Pedro;Sangregório,Bruno...
# 3  Casemiro,Bruno;Cunha,Maitê;Rinaldi,André;Lua,B...
# 4  Ruis,Carolina;Campos,Fábio;Volpato,Pedro;Caval...
#
#                                               German  \
# 0  Gerick,Wanja;Turba,David;Häcke,Maximiliane;Mai...
# 1                                                NaN
# 2                                                NaN
# 3  Wirthgen,Jesco;Bäcker,Manuela;Gavrilis,Marios;...
# 4                                                NaN
#
#                                            Hungarian  \
# 0  Baráth,István;Szabó,Máté;Faragó,András;Varga,R...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              English  \
# 0  Whitehead,Maxey;Truncale,Lily;Mignogna,Vic;Hof...
# 1  Loewen,Jocelyne;Daingerfield,Michael;Pitre,Sab...
# 2  Nishimura,Trina;Grelle,Josh;Mercer,Matthew;Pap...
# 3  Rinehart,Tyson;Nishimura,Trina;Tatum,JohnMicha...
# 4        Yeung,Suzie;Sabat,Christopher;Leigh,Cherami
#
#                                               Korean  \
# 0  Yun,MiNa;O,InSeong;Yang,JeongHwa;Lee,JiYeong;H...
# 1                                                NaN
# 2                                                NaN
# 3  Wu,JeongSin;Hong,SiHo;Yeo,MinJeong;Kim,SeoYeon...
# 4                                                NaN
#
#                                              Spanish  \
# 0  Torres,Jhonny;Vieira,JoseManuel;Perez,LuisMigu...
# 1                                                NaN
# 2                                                NaN
# 3                                         Naro,Jordi
# 4                                                NaN
#
#                                               French Mandarin Hebrew  \
# 0  Pic,Audrey;Boudonnat,Lucille;Pestel,Arthur;Cre...      NaN    NaN
# 1                                                NaN      NaN    NaN
# 2  Bienaimé,Nathalie;Niverd,Victor;Méyère,Bruno;G...      NaN    NaN
# 3  Pasquier,Laurent;Cornibert,Sarah;Wilhelm,Marc;...      NaN    NaN
# 4                                                NaN      NaN    NaN
#
#                                             Producer  \
# 0                         Cook,Justin;Yonai,Noritomo
# 1                                                NaN
# 2  Morishita,Katsuji;Nakatake,Tetsuya;Wada,Jouji;...
# 3                          Iwasa,Gaku;Yasuda,Takeshi
# 4                                                NaN
#
#                           Director  \
# 0                    Irie,Yasuhiro
# 1  Fujita,Youichi;Miyawaki,Chizuru
# 2   Araki,Tetsurou;Koizuka,Masashi
# 3    Hamasaki,Hiroshi;Satou,Takuya
# 4                  Ibata,Yoshihide
#
#                                      EpisodeDirector  \
# 0  Irie,Yasuhiro;Ikehata,Hiroshi;Ikezoe,Takahiro;...
# 1  Asami,Matsuo;Koshida,Tomoaki;Minami,Yasuhiro;M...
# 2  Araki,Tetsurou;Itoga,Shintaro;Tanaka,Hiroyuki;...
# 3  Hamasaki,Hiroshi;Satou,Takuya;Kobayashi,Kouji;...
# 4                                                NaN
#
#                                           Storyboard      SoundDirector  \
# 0  Irie,Yasuhiro;Ikezoe,Takahiro;Kinutani,Soushi;...      Mima,Masafumi
# 1    Fujita,Youichi;Miyawaki,Chizuru;Minami,Yasuhiro   Takamatsu,Shinji
# 2  Araki,Tetsurou;Akamatsu,Yasuhiro;Komatsuda,Dai...      Mima,Masafumi
# 3  Hamasaki,Hiroshi;Satou,Takuya;Kobayashi,Tomoki...  Fujiyama,Fusanobu
# 4                                                NaN      Aketagawa,Jin
#
#                                         KeyAnimation  \
# 0  Ikezoe,Takahiro;Kinutani,Soushi;Morii,Kenshiro...
# 1  Miyawaki,Chizuru;Abe,Miyuki;Hayashi,Kanako;Hay...
# 2   Imai,Arifumi;Izawa,Tamami;Oota,Emi;Yamauchi,Ryou
# 3  Hamasaki,Hiroshi;Aono,Atsushi;Arai,Nobuhiro;Hi...
# 4                                                NaN
#
#                                      2ndKeyAnimation  \
# 0  Ikezoe,Takahiro;Akasaka,Shunji;Kameda,Yoshimic...
# 1     Hayashi,Kanako;Honjou,Keiichirou;Sasaki,Youhei
# 2                                                NaN
# 3                      Hamaguchi,Akira;Satou,Hiroaki
# 4                                                NaN
#
#                 CharacterDesign  \
# 0  Morii,Kenshirou;Kanno,Hiroki
# 1               Takeuchi,Shinji
# 2                  Asano,Kyouji
# 3                  Sakai,Kyuuta
# 4                   Shindou,Yuu
#
#                                               Script SeriesComposition  \
# 0  Burgmeier,John;Minakami,Seishi;Oonogi,Hiroshi;...    Oonogi,Hiroshi
# 1         Kishimoto,Taku;Matsubara,Shuu;Mieno,Hitomi               NaN
# 2                      Kobayashi,Yasuko;Seko,Hiroshi  Kobayashi,Yasuko
# 3  Hanada,Jukki;Nemoto,Toshizou;Tatum,JohnMichael...      Hanada,Jukki
# 4                                                NaN    Kishimoto,Taku
#
#                                      ThemeSongLyrics  \
# 0  CHEMISTRY;NICOTouchestheWalls;SCANDAL;SID;Suki...
# 1              AquaTimez;BLUEENCOUNT;DOES;HoneyWorks
# 2                                                NaN
# 3                                  Shikura,Chiyomaru
# 4                                                NaN
#
#                                 ThemeSongPerformance  \
# 0  CHEMISTRY;Fukuhara,Miho;["LilB";NICOTouchesthe...
# 1  AquaTimez;BLUEENCOUNT;CHiCO;DOES;HoneyWorks;Ne...
# 2                          CinemaStaff;LinkedHorizon
# 3                         Itou,Kanako;Sakakibara,Yui
# 4                                      GENIC;WARPsUP
#
#                                 ThemeSongArrangement  \
# 0  Kameda,Seiji;NICOTouchestheWalls;SID;SukimaSwitch
# 1        AquaTimez;BLUEENCOUNT;DOES;HoneyWorks;Swimy
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                        ThemeSongComposition  \
# 0  NICOTouchestheWalls;SID;SukimaSwitch;Yui
# 1     AquaTimez;BLUEENCOUNT;DOES;HoneyWorks
# 2                                       NaN
# 3                         Shikura,Chiyomaru
# 4                                       NaN
#
#                                    AnimationDirector  \
# 0  Aono,Atsushi;Iijima,Hiroya;Ishino,Satoshi;Koba...
# 1  Honjou,Keiichirou;Ikeuchi,Naoko;Ishikawa,Marik...
# 2  Koizuka,Masashi;Chiba,Takaaki;Ebisu,Takuma;Has...
# 3  Aono,Atsushi;Arai,Nobuhiro;Igari,Takashi;Ikega...
# 4                                                NaN
#
#                     OriginalCreator  \
# 0                    Arakawa,Hiromu
# 1                   Sorachi,Hideaki
# 2                    Isayama,Hajime
# 3  Shikura,Chiyomaru;5pb.;Nitroplus
# 4                    Takaya,Natsuki
#
#                                          ADRDirector   ExecutiveProducer  \
# 0  Bezerra,Úrsula;Campos,Marcelo;Glass,Caitlin;Ka...        Fukunaga,Gen
# 1                                                NaN                 NaN
# 2                                  Sangregório,Bruno  Ishikawa,Mitsuhisa
# 3                 Clinkenbeard,Colleen;Rinaldi,André        Fukunaga,Gen
# 4                                       Falcão,Jonas                 NaN
#
#                             ChiefAnimationDirector     DirectorofPhotography  \
# 0  Fukuoka,Hidenori;Kameda,Yoshimichi;Kaneda,Naomi           Furumoto,Mayuko
# 1                                              NaN            Teramoto,Yuuki
# 2                    Asano,Kyouji;Kadowaki,Satoshi           Yamada,Kazuhiro
# 3                                     Sakai,Kyuuta          Nakamura,Keisuke
# 4                                              NaN  Cai,Bolun;Shitara,Nozomi
#
#                                  In-BetweenAnimation  \
# 0  Kameda,Yoshimichi;Oosawa,Mina;Saitou,Kengo;Yok...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        BackgroundArt  \
# 0  Kanehira,Kazushige;Nakajima,Mika;Ooizumi,Anna;...
# 1                                                NaN
# 2                                      Fujii,Kazushi
# 3  Kanehira,Kazushige;Kouji,Etou;Maeda,Yuki;Nemot...
# 4                                        Fujii,Yuuta
#
#                            Planning        ColorDesign  \
# 0        Minami,Masahiko;Ueda,Masuo       Nakao,Fusako
# 1                    Fujita,Youichi    Utagawa,Ritsuko
# 2                 Morishita,Katsuji  Hashimoto,Satoshi
# 3  Yasuda,Takeshi;Shikura,Chiyomaru       Satou,Miyuki
# 4                               NaN      Sugawara,Mika
#
#                           AssistantAnimationDirector         Editing  \
# 0                     Park,Seong-Hu;Yoshioka,Takeshi   Sadamatsu,Gou
# 1                                      Nakamura,Yumi  Seyama,Takeshi
# 2                                                NaN        Hida,Aya
# 3  Ikegami,Tarou;Nakamura,Kazuhisa;Sakai,Kyuuta;Y...             NaN
# 4                                                NaN        Hida,Aya
#
#                        ArtDirector            Music ProductionCoordination  \
# 0                    Satou,Takeshi      Senju,Akira             Shinya,Une
# 1  Fukushima,Takayoshi;Maniwa,Nami       AudioHighs                    NaN
# 2            Yoshihara,Shunichirou  Sawano,Hiroyuki                    NaN
# 3                       Kouji,Etou      Abo,Takeshi                    NaN
# 4                   Kamiyama,Youko  Yokoyama,Masaru                    NaN
#
#     DigitalPaint     ColorSetting                AssistantDirector  \
# 0  Uemura,Takako              NaN                              NaN
# 1            NaN  Utagawa,Ritsuko                              NaN
# 2            NaN              NaN  Koizuka,Masashi;Tanaka,Hiroyuki
# 3            NaN              NaN                              NaN
# 4            NaN              NaN                              NaN
#
#        SoundEffects InsertedSongPerformance OriginalCharacterDesign Setting  \
# 0               NaN                     NaN                     NaN     NaN
# 1               NaN                     NaN                     NaN     NaN
# 2  Kurahashi,Shizuo                     NaN                     NaN     NaN
# 3               NaN          JunjounoAfilia                    huke     NaN
# 4               NaN                     NaN                     NaN     NaN
#
#   Screenplay AssociateProducer SpecialEffects AnimationCheck  \
# 0        NaN               NaN            NaN            NaN
# 1        NaN               NaN            NaN            NaN
# 2        NaN               NaN            NaN            NaN
# 3        NaN               NaN            NaN            NaN
# 4        NaN               NaN            NaN            NaN
#
#   ProductionAssistant SoundSupervisor PrincipleDrawing AssistantProducer  \
# 0                 NaN             NaN              NaN               NaN
# 1                 NaN             NaN              NaN               NaN
# 2                 NaN             NaN              NaN               NaN
# 3                 NaN             NaN              NaN               NaN
# 4                 NaN             NaN              NaN               NaN
#
#   ProductionManager SoundManager Co-Director SeriesProductionDirector  \
# 0               NaN          NaN         NaN                      NaN
# 1               NaN          NaN         NaN                      NaN
# 2               NaN          NaN         NaN                      NaN
# 3               NaN          NaN         NaN                      NaN
# 4               NaN          NaN         NaN                      NaN
#
#   MechanicalDesign PlanningProducer Layout ChiefProducer Recording  \
# 0              NaN              NaN    NaN           NaN       NaN
# 1              NaN              NaN    NaN           NaN       NaN
# 2              NaN              NaN    NaN           NaN       NaN
# 3              NaN              NaN    NaN           NaN       NaN
# 4              NaN              NaN    NaN           NaN       NaN
#
#   DialogueEditing RecordingEngineer Creator RecordingAssistant Publicity  \
# 0             NaN               NaN     NaN                NaN       NaN
# 1             NaN               NaN     NaN                NaN       NaN
# 2             NaN               NaN     NaN                NaN       NaN
# 3             NaN               NaN     NaN                NaN       NaN
# 4             NaN               NaN     NaN                NaN       NaN
#
#   Co-Producer CastingDirector Re-RecordingMixing AssistantProductionCoordinat  \
# 0         NaN             NaN                NaN                          NaN
# 1         NaN             NaN                NaN                          NaN
# 2         NaN             NaN                NaN                          NaN
# 3         NaN             NaN                NaN                          NaN
# 4         NaN             NaN                NaN                          NaN
#
#   SettingManager
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 90 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ranking                       500 non-null    int64
#  1   name                          500 non-null    object
#  2   producers                     500 non-null    object
#  3   votersCount                   500 non-null    int64
#  4   score                         500 non-null    float64
#  5   popularity                    500 non-null    int64
#  6   members                       500 non-null    int64
#  7   favorite                      500 non-null    int64
#  8   episodes                      495 non-null    float64
#  9   animeType                     500 non-null    object
#  10  premiredDate                  295 non-null    object
#  11  animeSource                   500 non-null    object
#  12  genres                        455 non-null    object
#  13  studios                       500 non-null    object
#  14  licenses                      333 non-null    object
#  15  rating                        500 non-null    object
#  16  Japanese                      468 non-null    object
#  17  Italian                       156 non-null    object
#  18  Portuguese(BR)                132 non-null    object
#  19  German                        164 non-null    object
#  20  Hungarian                     29 non-null     object
#  21  English                       269 non-null    object
#  22  Korean                        107 non-null    object
#  23  Spanish                       134 non-null    object
#  24  French                        210 non-null    object
#  25  Mandarin                      8 non-null      object
#  26  Hebrew                        8 non-null      object
#  27  Producer                      181 non-null    object
#  28  Director                      446 non-null    object
#  29  EpisodeDirector               313 non-null    object
#  30  Storyboard                    327 non-null    object
#  31  SoundDirector                 308 non-null    object
#  32  KeyAnimation                  375 non-null    object
#  33  2ndKeyAnimation               165 non-null    object
#  34  CharacterDesign               404 non-null    object
#  35  Script                        296 non-null    object
#  36  SeriesComposition             238 non-null    object
#  37  ThemeSongLyrics               209 non-null    object
#  38  ThemeSongPerformance          416 non-null    object
#  39  ThemeSongArrangement          175 non-null    object
#  40  ThemeSongComposition          220 non-null    object
#  41  AnimationDirector             346 non-null    object
#  42  OriginalCreator               441 non-null    object
#  43  ADRDirector                   222 non-null    object
#  44  ExecutiveProducer             126 non-null    object
#  45  ChiefAnimationDirector        221 non-null    object
#  46  DirectorofPhotography         243 non-null    object
#  47  In-BetweenAnimation           143 non-null    object
#  48  BackgroundArt                 217 non-null    object
#  49  Planning                      115 non-null    object
#  50  ColorDesign                   258 non-null    object
#  51  AssistantAnimationDirector    125 non-null    object
#  52  Editing                       214 non-null    object
#  53  ArtDirector                   303 non-null    object
#  54  Music                         402 non-null    object
#  55  ProductionCoordination        4 non-null      object
#  56  DigitalPaint                  18 non-null     object
#  57  ColorSetting                  40 non-null     object
#  58  AssistantDirector             105 non-null    object
#  59  SoundEffects                  159 non-null    object
#  60  InsertedSongPerformance       105 non-null    object
#  61  OriginalCharacterDesign       130 non-null    object
#  62  Setting                       30 non-null     object
#  63  Screenplay                    75 non-null     object
#  64  AssociateProducer             16 non-null     object
#  65  SpecialEffects                56 non-null     object
#  66  AnimationCheck                32 non-null     object
#  67  ProductionAssistant           18 non-null     object
#  68  SoundSupervisor               4 non-null      object
#  69  PrincipleDrawing              22 non-null     object
#  70  AssistantProducer             14 non-null     object
#  71  ProductionManager             15 non-null     object
#  72  SoundManager                  4 non-null      object
#  73  Co-Director                   6 non-null      object
#  74  SeriesProductionDirector      9 non-null      object
#  75  MechanicalDesign              54 non-null     object
#  76  PlanningProducer              6 non-null      object
#  77  Layout                        25 non-null     object
#  78  ChiefProducer                 19 non-null     object
#  79  Recording                     7 non-null      object
#  80  DialogueEditing               2 non-null      object
#  81  RecordingEngineer             9 non-null      object
#  82  Creator                       11 non-null     object
#  83  RecordingAssistant            4 non-null      object
#  84  Publicity                     10 non-null     object
#  85  Co-Producer                   6 non-null      object
#  86  CastingDirector               3 non-null      object
#  87  Re-RecordingMixing            1 non-null      object
#  88  AssistantProductionCoordinat  2 non-null      object
#  89  SettingManager                2 non-null      object
# dtypes: float64(2), int64(5), object(83)
# memory usage: 351.7+ KB

# %%
df.columns
# Out:
# Index(['ranking', 'name', 'producers', 'votersCount', 'score', 'popularity',
#        'members', 'favorite', 'episodes', 'animeType', 'premiredDate',
#        'animeSource', 'genres', 'studios', 'licenses', 'rating', 'Japanese',
#        'Italian', 'Portuguese(BR)', 'German', 'Hungarian', 'English', 'Korean',
#        'Spanish', 'French', 'Mandarin', 'Hebrew', 'Producer', 'Director',
#        'EpisodeDirector', 'Storyboard', 'SoundDirector', 'KeyAnimation',
#        '2ndKeyAnimation', 'CharacterDesign', 'Script', 'SeriesComposition',
#        'ThemeSongLyrics', 'ThemeSongPerformance', 'ThemeSongArrangement',
#        'ThemeSongComposition', 'AnimationDirector', 'OriginalCreator',
#        'ADRDirector', 'ExecutiveProducer', 'ChiefAnimationDirector',
#        'DirectorofPhotography', 'In-BetweenAnimation', 'BackgroundArt',
#        'Planning', 'ColorDesign', 'AssistantAnimationDirector', 'Editing',
#        'ArtDirector', 'Music', 'ProductionCoordination', 'DigitalPaint',
#        'ColorSetting', 'AssistantDirector', 'SoundEffects',
#        'InsertedSongPerformance', 'OriginalCharacterDesign', 'Setting',
#        'Screenplay', 'AssociateProducer', 'SpecialEffects', 'AnimationCheck',
#        'ProductionAssistant', 'SoundSupervisor', 'PrincipleDrawing',
#        'AssistantProducer', 'ProductionManager', 'SoundManager', 'Co-Director',
#        'SeriesProductionDirector', 'MechanicalDesign', 'PlanningProducer',
#        'Layout', 'ChiefProducer', 'Recording', 'DialogueEditing',
#        'RecordingEngineer', 'Creator', 'RecordingAssistant', 'Publicity',
#        'Co-Producer', 'CastingDirector', 'Re-RecordingMixing',
#        'AssistantProductionCoordinat', 'SettingManager'],
#       dtype='object')

# %% [markdown]
# ## 1- Qual a média de score dos animes?

# %%
df['score'].isnull().values.any()
# Out:
# False

# %%
df['score'].mean()
# Out:
# 8.335519999999994

# %% [markdown]
# ## 2- Qual o anime com maior número de votos?

# %%
df.loc[df['votersCount'].argmax()]
# Out:
# ranking                                                                       100
# name                                                           Shingeki no Kyojin
# producers                       ProductionI.G;Dentsu;MainichiBroadcastingSyste...
# votersCount                                                               2220982
# score                                                                        8.52
#                                                       ...
# Co-Producer                                                                   NaN
# CastingDirector                                                               NaN
# Re-RecordingMixing                                                            NaN
# AssistantProductionCoordinat                                                  NaN
# SettingManager                                                                NaN
# Name: 99, Length: 90, dtype: object

# %% [markdown]
# ## 3- Quais os tipos de animes?

# %%
df['animeType'].value_counts()
# Out:
# TV         295
# Movie      112
# OVA         37
# Special     28
# ONA         23
# Music        5
# Name: animeType, dtype: int64

# %% [markdown]
# ## 4- Qual a média de score por tipo de anime?

# %%
df.groupby(['animeType'])['score'].mean()
# Out:
# animeType
# Movie      8.335268
# Music      8.296000
# ONA        8.324348
# OVA        8.223514
# Special    8.225000
# TV         8.361695
# Name: score, dtype: float64

# %% [markdown]
# ## 5- Quais são as fontes dos animes?

# %%
df['animeSource'].value_counts()
# Out:
# Manga           282
# Original         67
# Light novel      56
# Novel            47
# Visual novel     15
# Web manga        12
# Other             7
# Game              4
# 4-koma manga      4
# Music             3
# Unknown           2
# Book              1
# Name: animeSource, dtype: int64

# %% [markdown]
# ## 6- Quantos animes estão disponíveis em português?

# %%
df['Portuguese(BR)'].value_counts().sum()
# Out:
# 132

# %% [markdown]
# ## 7- Quantos animes têm co-produtores (Co-Producer)?

# %%
df['Co-Producer'].value_counts().sum()
# Out:
# 6

# %% [markdown]
# ## 8- Há animes sem produtores?

# %%
df.head()
# Out:
#    ranking                                name  \
# 0        1    Fullmetal Alchemist: Brotherhood
# 1        2                            Gintama°
# 2        3  Shingeki no Kyojin Season 3 Part 2
# 3        4                         Steins;Gate
# 4        5            Fruits Basket: The Final
#
#                                            producers  votersCount  score  \
# 0  Aniplex;SquareEnix;MainichiBroadcastingSystem;...      1650275   9.15
# 1                             TVTokyo;Aniplex;Dentsu       173906   9.09
# 2  ProductionI.G;Dentsu;MainichiBroadcastingSyste...      1127900   9.09
# 3  FrontierWorks;MediaFactory;Movic;AT-X;Kadokawa...      1128557   9.09
# 4  TVTokyo;TVOsaka;NihonAdSystems;Hakusensha;Avex...       124091   9.06
#
#    popularity  members  favorite  episodes animeType premiredDate  \
# 0           3  2713695    191501      64.0        TV  Spring 2009
# 1         337   493336     13063      51.0        TV  Spring 2015
# 2          33  1635976     46238      10.0        TV  Spring 2019
# 3          12  2117018    162324      24.0        TV  Spring 2011
# 4         619   288314     13330      13.0        TV  Spring 2021
#
#     animeSource                                         genres  \
# 0         Manga          Action;Adventure;Comedy;Drama;Fantasy
# 1         Manga                           Action;Comedy;Sci-fi
# 2         Manga                   Action;Drama;Fantasy;Mystery
# 3  Visual novel                          Drama;Sci-fi;Suspense
# 4         Manga  Comedy;Drama;Romance;Sliceoflife;Supernatural
#
#                  studios                     licenses       rating  \
# 0                  Bones  Funimation;AniplexofAmerica        R-17+
# 1  Bandai Namco Pictures       Funimation;Crunchyroll  PG-13-Teens
# 2             Wit Studio                   Funimation        R-17+
# 3              White Fox                   Funimation  PG-13-Teens
# 4      TMS Entertainment                   Funimation  PG-13-Teens
#
#                                             Japanese  \
# 0  Kugimiya,Rie;Park,Romi;Utsumi,Kenji;Utsumi,Ken...
# 1  Kugimiya,Rie;Ishii,Kouji;Sugita,Tomokazu;Tomat...
# 2  Ishikawa,Yui;Inoue,Marina;Kamiya,Hiroshi;Kaji,...
# 3  Seki,Tomokazu;Imai,Asami;Miyano,Mamoru;Hanazaw...
# 4  Iwami,Manaka;Uchida,Yuuma;Shimazaki,Nobunaga;S...
#
#                                              Italian  \
# 0  Ponticelli,Benedetta;Novara,Renato;Scianca,Pat...
# 1                                                NaN
# 2  Perino,Elena;Bolognesi,Gaia;Raffaeli,Daniele;C...
# 3  Vivio,Paolo;Paolelli,Rachele;Chevalier,Davide;...
# 4                                                NaN
#
#                                       Portuguese(BR)  \
# 0  Andreatto,Rodrigo;Campos,Marcelo;Zink,Mariana;...
# 1                                                NaN
# 2  Stefane,Mayara;Volpato,Pedro;Sangregório,Bruno...
# 3  Casemiro,Bruno;Cunha,Maitê;Rinaldi,André;Lua,B...
# 4  Ruis,Carolina;Campos,Fábio;Volpato,Pedro;Caval...
#
#                                               German  \
# 0  Gerick,Wanja;Turba,David;Häcke,Maximiliane;Mai...
# 1                                                NaN
# 2                                                NaN
# 3  Wirthgen,Jesco;Bäcker,Manuela;Gavrilis,Marios;...
# 4                                                NaN
#
#                                            Hungarian  \
# 0  Baráth,István;Szabó,Máté;Faragó,András;Varga,R...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              English  \
# 0  Whitehead,Maxey;Truncale,Lily;Mignogna,Vic;Hof...
# 1  Loewen,Jocelyne;Daingerfield,Michael;Pitre,Sab...
# 2  Nishimura,Trina;Grelle,Josh;Mercer,Matthew;Pap...
# 3  Rinehart,Tyson;Nishimura,Trina;Tatum,JohnMicha...
# 4        Yeung,Suzie;Sabat,Christopher;Leigh,Cherami
#
#                                               Korean  \
# 0  Yun,MiNa;O,InSeong;Yang,JeongHwa;Lee,JiYeong;H...
# 1                                                NaN
# 2                                                NaN
# 3  Wu,JeongSin;Hong,SiHo;Yeo,MinJeong;Kim,SeoYeon...
# 4                                                NaN
#
#                                              Spanish  \
# 0  Torres,Jhonny;Vieira,JoseManuel;Perez,LuisMigu...
# 1                                                NaN
# 2                                                NaN
# 3                                         Naro,Jordi
# 4                                                NaN
#
#                                               French Mandarin Hebrew  \
# 0  Pic,Audrey;Boudonnat,Lucille;Pestel,Arthur;Cre...      NaN    NaN
# 1                                                NaN      NaN    NaN
# 2  Bienaimé,Nathalie;Niverd,Victor;Méyère,Bruno;G...      NaN    NaN
# 3  Pasquier,Laurent;Cornibert,Sarah;Wilhelm,Marc;...      NaN    NaN
# 4                                                NaN      NaN    NaN
#
#                                             Producer  \
# 0                         Cook,Justin;Yonai,Noritomo
# 1                                                NaN
# 2  Morishita,Katsuji;Nakatake,Tetsuya;Wada,Jouji;...
# 3                          Iwasa,Gaku;Yasuda,Takeshi
# 4                                                NaN
#
#                           Director  \
# 0                    Irie,Yasuhiro
# 1  Fujita,Youichi;Miyawaki,Chizuru
# 2   Araki,Tetsurou;Koizuka,Masashi
# 3    Hamasaki,Hiroshi;Satou,Takuya
# 4                  Ibata,Yoshihide
#
#                                      EpisodeDirector  \
# 0  Irie,Yasuhiro;Ikehata,Hiroshi;Ikezoe,Takahiro;...
# 1  Asami,Matsuo;Koshida,Tomoaki;Minami,Yasuhiro;M...
# 2  Araki,Tetsurou;Itoga,Shintaro;Tanaka,Hiroyuki;...
# 3  Hamasaki,Hiroshi;Satou,Takuya;Kobayashi,Kouji;...
# 4                                                NaN
#
#                                           Storyboard      SoundDirector  \
# 0  Irie,Yasuhiro;Ikezoe,Takahiro;Kinutani,Soushi;...      Mima,Masafumi
# 1    Fujita,Youichi;Miyawaki,Chizuru;Minami,Yasuhiro   Takamatsu,Shinji
# 2  Araki,Tetsurou;Akamatsu,Yasuhiro;Komatsuda,Dai...      Mima,Masafumi
# 3  Hamasaki,Hiroshi;Satou,Takuya;Kobayashi,Tomoki...  Fujiyama,Fusanobu
# 4                                                NaN      Aketagawa,Jin
#
#                                         KeyAnimation  \
# 0  Ikezoe,Takahiro;Kinutani,Soushi;Morii,Kenshiro...
# 1  Miyawaki,Chizuru;Abe,Miyuki;Hayashi,Kanako;Hay...
# 2   Imai,Arifumi;Izawa,Tamami;Oota,Emi;Yamauchi,Ryou
# 3  Hamasaki,Hiroshi;Aono,Atsushi;Arai,Nobuhiro;Hi...
# 4                                                NaN
#
#                                      2ndKeyAnimation  \
# 0  Ikezoe,Takahiro;Akasaka,Shunji;Kameda,Yoshimic...
# 1     Hayashi,Kanako;Honjou,Keiichirou;Sasaki,Youhei
# 2                                                NaN
# 3                      Hamaguchi,Akira;Satou,Hiroaki
# 4                                                NaN
#
#                 CharacterDesign  \
# 0  Morii,Kenshirou;Kanno,Hiroki
# 1               Takeuchi,Shinji
# 2                  Asano,Kyouji
# 3                  Sakai,Kyuuta
# 4                   Shindou,Yuu
#
#                                               Script SeriesComposition  \
# 0  Burgmeier,John;Minakami,Seishi;Oonogi,Hiroshi;...    Oonogi,Hiroshi
# 1         Kishimoto,Taku;Matsubara,Shuu;Mieno,Hitomi               NaN
# 2                      Kobayashi,Yasuko;Seko,Hiroshi  Kobayashi,Yasuko
# 3  Hanada,Jukki;Nemoto,Toshizou;Tatum,JohnMichael...      Hanada,Jukki
# 4                                                NaN    Kishimoto,Taku
#
#                                      ThemeSongLyrics  \
# 0  CHEMISTRY;NICOTouchestheWalls;SCANDAL;SID;Suki...
# 1              AquaTimez;BLUEENCOUNT;DOES;HoneyWorks
# 2                                                NaN
# 3                                  Shikura,Chiyomaru
# 4                                                NaN
#
#                                 ThemeSongPerformance  \
# 0  CHEMISTRY;Fukuhara,Miho;["LilB";NICOTouchesthe...
# 1  AquaTimez;BLUEENCOUNT;CHiCO;DOES;HoneyWorks;Ne...
# 2                          CinemaStaff;LinkedHorizon
# 3                         Itou,Kanako;Sakakibara,Yui
# 4                                      GENIC;WARPsUP
#
#                                 ThemeSongArrangement  \
# 0  Kameda,Seiji;NICOTouchestheWalls;SID;SukimaSwitch
# 1        AquaTimez;BLUEENCOUNT;DOES;HoneyWorks;Swimy
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                        ThemeSongComposition  \
# 0  NICOTouchestheWalls;SID;SukimaSwitch;Yui
# 1     AquaTimez;BLUEENCOUNT;DOES;HoneyWorks
# 2                                       NaN
# 3                         Shikura,Chiyomaru
# 4                                       NaN
#
#                                    AnimationDirector  \
# 0  Aono,Atsushi;Iijima,Hiroya;Ishino,Satoshi;Koba...
# 1  Honjou,Keiichirou;Ikeuchi,Naoko;Ishikawa,Marik...
# 2  Koizuka,Masashi;Chiba,Takaaki;Ebisu,Takuma;Has...
# 3  Aono,Atsushi;Arai,Nobuhiro;Igari,Takashi;Ikega...
# 4                                                NaN
#
#                     OriginalCreator  \
# 0                    Arakawa,Hiromu
# 1                   Sorachi,Hideaki
# 2                    Isayama,Hajime
# 3  Shikura,Chiyomaru;5pb.;Nitroplus
# 4                    Takaya,Natsuki
#
#                                          ADRDirector   ExecutiveProducer  \
# 0  Bezerra,Úrsula;Campos,Marcelo;Glass,Caitlin;Ka...        Fukunaga,Gen
# 1                                                NaN                 NaN
# 2                                  Sangregório,Bruno  Ishikawa,Mitsuhisa
# 3                 Clinkenbeard,Colleen;Rinaldi,André        Fukunaga,Gen
# 4                                       Falcão,Jonas                 NaN
#
#                             ChiefAnimationDirector     DirectorofPhotography  \
# 0  Fukuoka,Hidenori;Kameda,Yoshimichi;Kaneda,Naomi           Furumoto,Mayuko
# 1                                              NaN            Teramoto,Yuuki
# 2                    Asano,Kyouji;Kadowaki,Satoshi           Yamada,Kazuhiro
# 3                                     Sakai,Kyuuta          Nakamura,Keisuke
# 4                                              NaN  Cai,Bolun;Shitara,Nozomi
#
#                                  In-BetweenAnimation  \
# 0  Kameda,Yoshimichi;Oosawa,Mina;Saitou,Kengo;Yok...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        BackgroundArt  \
# 0  Kanehira,Kazushige;Nakajima,Mika;Ooizumi,Anna;...
# 1                                                NaN
# 2                                      Fujii,Kazushi
# 3  Kanehira,Kazushige;Kouji,Etou;Maeda,Yuki;Nemot...
# 4                                        Fujii,Yuuta
#
#                            Planning        ColorDesign  \
# 0        Minami,Masahiko;Ueda,Masuo       Nakao,Fusako
# 1                    Fujita,Youichi    Utagawa,Ritsuko
# 2                 Morishita,Katsuji  Hashimoto,Satoshi
# 3  Yasuda,Takeshi;Shikura,Chiyomaru       Satou,Miyuki
# 4                               NaN      Sugawara,Mika
#
#                           AssistantAnimationDirector         Editing  \
# 0                     Park,Seong-Hu;Yoshioka,Takeshi   Sadamatsu,Gou
# 1                                      Nakamura,Yumi  Seyama,Takeshi
# 2                                                NaN        Hida,Aya
# 3  Ikegami,Tarou;Nakamura,Kazuhisa;Sakai,Kyuuta;Y...             NaN
# 4                                                NaN        Hida,Aya
#
#                        ArtDirector            Music ProductionCoordination  \
# 0                    Satou,Takeshi      Senju,Akira             Shinya,Une
# 1  Fukushima,Takayoshi;Maniwa,Nami       AudioHighs                    NaN
# 2            Yoshihara,Shunichirou  Sawano,Hiroyuki                    NaN
# 3                       Kouji,Etou      Abo,Takeshi                    NaN
# 4                   Kamiyama,Youko  Yokoyama,Masaru                    NaN
#
#     DigitalPaint     ColorSetting                AssistantDirector  \
# 0  Uemura,Takako              NaN                              NaN
# 1            NaN  Utagawa,Ritsuko                              NaN
# 2            NaN              NaN  Koizuka,Masashi;Tanaka,Hiroyuki
# 3            NaN              NaN                              NaN
# 4            NaN              NaN                              NaN
#
#        SoundEffects InsertedSongPerformance OriginalCharacterDesign Setting  \
# 0               NaN                     NaN                     NaN     NaN
# 1               NaN                     NaN                     NaN     NaN
# 2  Kurahashi,Shizuo                     NaN                     NaN     NaN
# 3               NaN          JunjounoAfilia                    huke     NaN
# 4               NaN                     NaN                     NaN     NaN
#
#   Screenplay AssociateProducer SpecialEffects AnimationCheck  \
# 0        NaN               NaN            NaN            NaN
# 1        NaN               NaN            NaN            NaN
# 2        NaN               NaN            NaN            NaN
# 3        NaN               NaN            NaN            NaN
# 4        NaN               NaN            NaN            NaN
#
#   ProductionAssistant SoundSupervisor PrincipleDrawing AssistantProducer  \
# 0                 NaN             NaN              NaN               NaN
# 1                 NaN             NaN              NaN               NaN
# 2                 NaN             NaN              NaN               NaN
# 3                 NaN             NaN              NaN               NaN
# 4                 NaN             NaN              NaN               NaN
#
#   ProductionManager SoundManager Co-Director SeriesProductionDirector  \
# 0               NaN          NaN         NaN                      NaN
# 1               NaN          NaN         NaN                      NaN
# 2               NaN          NaN         NaN                      NaN
# 3               NaN          NaN         NaN                      NaN
# 4               NaN          NaN         NaN                      NaN
#
#   MechanicalDesign PlanningProducer Layout ChiefProducer Recording  \
# 0              NaN              NaN    NaN           NaN       NaN
# 1              NaN              NaN    NaN           NaN       NaN
# 2              NaN              NaN    NaN           NaN       NaN
# 3              NaN              NaN    NaN           NaN       NaN
# 4              NaN              NaN    NaN           NaN       NaN
#
#   DialogueEditing RecordingEngineer Creator RecordingAssistant Publicity  \
# 0             NaN               NaN     NaN                NaN       NaN
# 1             NaN               NaN     NaN                NaN       NaN
# 2             NaN               NaN     NaN                NaN       NaN
# 3             NaN               NaN     NaN                NaN       NaN
# 4             NaN               NaN     NaN                NaN       NaN
#
#   Co-Producer CastingDirector Re-RecordingMixing AssistantProductionCoordinat  \
# 0         NaN             NaN                NaN                          NaN
# 1         NaN             NaN                NaN                          NaN
# 2         NaN             NaN                NaN                          NaN
# 3         NaN             NaN                NaN                          NaN
# 4         NaN             NaN                NaN                          NaN
#
#   SettingManager
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
df["producers"]
# Out:
# 0      Aniplex;SquareEnix;MainichiBroadcastingSystem;...
# 1                                 TVTokyo;Aniplex;Dentsu
# 2      ProductionI.G;Dentsu;MainichiBroadcastingSyste...
# 3      FrontierWorks;MediaFactory;Movic;AT-X;Kadokawa...
# 4      TVTokyo;TVOsaka;NihonAdSystems;Hakusensha;Avex...
#                              ...
# 495                                                  NHK
# 496                                              TVAsahi
# 497                                       NHK;SogoVision
# 498    TVTokyo;GeneonUniversalEntertainment;Shogakuka...
# 499                                    Nonefound;addsome
# Name: producers, Length: 500, dtype: object

# %%
df[df["producers"].str.contains("Nonefound")]
# Out:
#      ranking                                               name  \
# 29        30    Mushoku Tensei: Isekai Ittara Honki Dasu Part 2
# 61        62                      Kimetsu no Yaiba: Yuukaku-hen
# 114      115                                     Hotaru no Haka
# 117      118                            Gintama: The Semi-Final
# 122      123  Kono Subarashii Sekai ni Shukufuku wo! Movie: ...
# ..       ...                                                ...
# 478      479                                 Kyou kara Ore wa!!
# 479      480                                     Pui Pui Molcar
# 484      485            Saint Seiya: Meiou Hades Juuni Kyuu-hen
# 489      490  Detective Conan Movie 10: Requiem of the Detec...
# 499      500  Kono Subarashii Sekai ni Shukufuku wo! 2: Kono...
#
#              producers  votersCount  score  popularity  members  favorite  \
# 29   Nonefound;addsome        76025   8.79         438   386457      7617
# 61   Nonefound;addsome        31470   8.65         456   373785      6210
# 114  Nonefound;addsome       319828   8.50         303   537306      6103
# 117  Nonefound;addsome        19715   8.49        2652    46214       203
# 122  Nonefound;addsome       358980   8.48         261   583145      4032
# ..                 ...          ...    ...         ...      ...       ...
# 478  Nonefound;addsome         8471   8.06        3483    27403       320
# 479  Nonefound;addsome         5438   8.06        5422     9758       179
# 484  Nonefound;addsome        31030   8.05        2515    50047       328
# 489  Nonefound;addsome        27897   8.05        2586    48030        38
# 499  Nonefound;addsome       181125   8.04         583   300041       683
#
#      episodes animeType premiredDate  animeSource  \
# 29       12.0        TV    Fall 2021  Light novel
# 61        NaN        TV  Winter 2022        Manga
# 114       1.0     Movie          NaN        Novel
# 117       2.0   Special          NaN        Manga
# 122       1.0     Movie          NaN  Light novel
# ..        ...       ...          ...          ...
# 478      10.0       OVA          NaN        Manga
# 479      12.0        TV  Winter 2021        Other
# 484      13.0       OVA          NaN        Manga
# 489       1.0     Movie          NaN        Manga
# 499       1.0       OVA          NaN  Light novel
#
#                                     genres                studios  \
# 29                     Drama;Fantasy;Ecchi            Studio Bind
# 61                     Action;Supernatural               ufotable
# 114                                    NaN          Studio Ghibli
# 117                          Action;Comedy  Bandai Namco Pictures
# 122  Adventure;Comedy;Fantasy;Supernatural              J.C.Staff
# ..                                     ...                    ...
# 478                                    NaN         Studio Pierrot
# 479                                    NaN      Shin-Ei Animation
# 484                       Adventure;Sci-fi         Toei Animation
# 489               Adventure;Comedy;Mystery      TMS Entertainment
# 499  Adventure;Comedy;Fantasy;Supernatural            Studio Deen
#
#                                       licenses       rating  \
# 29                                  Funimation        R-17+
# 61                                         NaN        R-17+
# 114  ADVFilms;CentralParkMedia;SentaiFilmworks  PG-13-Teens
# 117                                        NaN  PG-13-Teens
# 122                                        NaN  PG-13-Teens
# ..                                         ...          ...
# 478                                        NaN        R-17+
# 479                          MuseCommunication        G-All
# 484                                        NaN  PG-13-Teens
# 489                                        NaN  PG-13-Teens
# 499                              DiscotekMedia  PG-13-Teens
#
#                                               Japanese  \
# 29               Uchiyama,Yumi;Kakuma,Ai;Kohara,Konomi
# 61   Shimono,Hiro;Matsuoka,Yoshitsugu;Hanae,Natsuki...
# 114                    Tatsumi,Tsutomu;Shiraishi,Ayano
# 117  Sugita,Tomokazu;Tachiki,Fumihiko;Nakai,Kazuya;...
# 122  Amamiya,Sora;Kayano,Ai;Takahashi,Rie;Fukushima...
# ..                                                 ...
# 478  Hori,Hideyuki;Matsumoto,Yasunori;Kusachi,Fumie...
# 479                                                NaN
# 484  Horikawa,Ryo;Yamazaki,Takumi;Hashimoto,Kouichi...
# 489  Takayama,Minami;Yamaguchi,Kappei;Horikawa,Ryo;...
# 499  Amamiya,Sora;Kayano,Ai;Takahashi,Rie;Fukushima...
#
#                                                Italian  \
# 29                                                 NaN
# 61                                                 NaN
# 114  Conforti,Corrado;Caneva,Leonardo;Liberatori,Pe...
# 117                                                NaN
# 122                                                NaN
# ..                                                 ...
# 478  Bonino,Giorgio;Cortese,Marcello;Olivieri,Elda;...
# 479                                                NaN
# 484  DeNisco,Andrea;Rosa,Luigi;Balzarotti,Marco;Mag...
# 489  Garbolino,Davide;Scalzo,Irene;"DAndrea,Simone"...
# 499                                                NaN
#
#                                         Portuguese(BR)  \
# 29   Henrique,Celso;Magno,Carloz;Tavares,Amanda;Pel...
# 61                                                 NaN
# 114                                                NaN
# 117                                                NaN
# 122  Alves,Natália;Bougleux,Erick;Júnior,Francisco;...
# ..                                                 ...
# 478                                                NaN
# 479                                                NaN
# 484  Bezerra,Ulisses;Campos,Marcelo;Brêtas,Francisc...
# 489                                                NaN
# 499  Alves,Natália;Simi,Isabella;Bougleux,Erick;Ghe...
#
#                                                 German  \
# 29                                                 NaN
# 61                                                 NaN
# 114                    Schmidt-Foß,Gerrit;Azdasht,Adak
# 117                                                NaN
# 122                                                NaN
# ..                                                 ...
# 478                                                NaN
# 479                                                NaN
# 484                                                NaN
# 489  Müller,Tobias;Kahnmeyer,Robin;Jakobeit,Giulian...
# 499                                                NaN
#
#                          Hungarian  \
# 29                             NaN
# 61                             NaN
# 114  Crespo,Rodrigo;Ungvári,Zsófia
# 117                            NaN
# 122                            NaN
# ..                             ...
# 478                            NaN
# 479                            NaN
# 484                            NaN
# 489                            NaN
# 499                            NaN
#
#                                                English  \
# 29                                                 NaN
# 61                                                 NaN
# 114            Spencer,J.Robert;Gibbs,Adam;Neves,Emily
# 117                                                NaN
# 122  Mata,Faye;Valenzuela,Cristina;Mendez,Erica;Pan...
# ..                                                 ...
# 478                                                NaN
# 479                                                NaN
# 484                                                NaN
# 489                                                NaN
# 499  Mata,Faye;Valenzuela,Cristina;Mendez,Erica;Pan...
#
#                        Korean  \
# 29                        NaN
# 61                        NaN
# 114       Kim,Il;Kim,SeoYeong
# 117                       NaN
# 122                       NaN
# ..                        ...
# 478                       NaN
# 479                       NaN
# 484                       NaN
# 489  Wu,JeongSin;Yeo,MinJeong
# 499                       NaN
#
#                                                Spanish  \
# 29                                                 NaN
# 61                                                 NaN
# 114                  TrifolSegarra,Albert;Trifol,Nuria
# 117                                                NaN
# 122                                                NaN
# ..                                                 ...
# 478                                                NaN
# 479                                                NaN
# 484  Vilchis,JoséGilberto;Prieto,Alan;López,Jonatán...
# 489                                                NaN
# 499                                                NaN
#
#                                                 French Mandarin Hebrew  \
# 29   Matthys,Nicolas;Guillaume,Émilie;Philippot,Nan...      NaN    NaN
# 61                                                 NaN      NaN    NaN
# 114                           Grull,Pascal;Marot,Kelly      NaN    NaN
# 117                                                NaN      NaN    NaN
# 122                                                NaN      NaN    NaN
# ..                                                 ...      ...    ...
# 478                                                NaN      NaN    NaN
# 479                                                NaN      NaN    NaN
# 484  Haùgness,Frederik;Dacquin,Franck;Moreau,Mathie...      NaN    NaN
# 489                                                NaN      NaN    NaN
# 499                                                NaN      NaN    NaN
#
#            Producer             Director  \
# 29              NaN                  NaN
# 61              NaN       Sotozaki,Haruo
# 114             NaN        Takahata,Isao
# 117             NaN                  NaN
# 122             NaN     Kanasaki,Takaomi
# ..              ...                  ...
# 478             NaN         Mori,Takeshi
# 479             NaN        Misato,Tomoki
# 484             NaN   Yamauchi,Shigeyasu
# 489  Suwa,Michihiko  Yamamoto,Yasuichiro
# 499             NaN     Kanasaki,Takaomi
#
#                                       EpisodeDirector  \
# 29                                                NaN
# 61                                                NaN
# 114                                               NaN
# 117                                               NaN
# 122                                               NaN
# ..                                                ...
# 478                                               NaN
# 479                                               NaN
# 484  Yamauchi,Shigeyasu;Itou,Naoyuki;Nagamine,Tatsuya
# 489                                               NaN
# 499                                               NaN
#
#                                             Storyboard      SoundDirector  \
# 29                                                 NaN      Aketagawa,Jin
# 61                                                 NaN                NaN
# 114                                                NaN      Urakami,Yasuo
# 117                                                NaN                NaN
# 122                                                NaN                NaN
# ..                                                 ...                ...
# 478                                                NaN  Fujiyama,Fusanobu
# 479                                                NaN      Noguchi,Akira
# 484                                 Yamauchi,Shigeyasu                NaN
# 489  Yamamoto,Yasuichiro;Nishimori,Akira;Okuwaki,Ma...                NaN
# 499                                                NaN  Iwanami,Yoshikazu
#
#                                           KeyAnimation 2ndKeyAnimation  \
# 29                                                 NaN             NaN
# 61                                                 NaN             NaN
# 114  Anno,Hideaki;Ishiguro,Megumu;Kigami,Yoshiji;Ko...             NaN
# 117                                                NaN             NaN
# 122                                                NaN             NaN
# ..                                                 ...             ...
# 478  Nakayama,Katsuichi;Tetsuhito,Saito;Tsurumaki,K...             NaN
# 479                                                NaN             NaN
# 484                                                NaN             NaN
# 489  Akiyama,Yukiko;Fujioka,Maki;Furumata,Taichi;Fu...             NaN
# 499                                    Murata,Noriyasu  Yamamoto,Saori
#
#                                        CharacterDesign            Script  \
# 29   Saitou,Yochiko;Sugiyama,Kazutaka;Takahashi,Mizuki  Pettini,Emmanuel
# 61                                    Matsushima,Akira               NaN
# 114                                   Kondou,Yoshifumi               NaN
# 117                                    Takeuchi,Shinji               NaN
# 122                                     Kikuta,Kouichi       Uezu,Makoto
# ..                                                 ...               ...
# 478                                      Onishi,Masaya               NaN
# 479                                                NaN               NaN
# 484                                       Araki,Shingo    Yokote,Michiko
# 489                                     Sudou,Masatomo               NaN
# 499                                     Kikuta,Kouichi               NaN
#
#     SeriesComposition ThemeSongLyrics  \
# 29     Okamoto,Manabu             NaN
# 61                NaN    Kajiura,Yuki
# 114               NaN             NaN
# 117               NaN             NaN
# 122               NaN             NaN
# ..                ...             ...
# 478               NaN             NaN
# 479               NaN             NaN
# 484    Yokote,Michiko             NaN
# 489               NaN             NaN
# 499               NaN             NaN
#
#                              ThemeSongPerformance ThemeSongArrangement  \
# 29                                            NaN                  NaN
# 61                             Aimer;Kajiura,Yuki         Kajiura,Yuki
# 114                                           NaN        Mamiya,Michio
# 117                                           NaN                  NaN
# 122  Amamiya,Sora;Kayano,Ai;Machico;Takahashi,Rie                  NaN
# ..                                            ...                  ...
# 478                                           NaN                  NaN
# 479                                           NaN                  NaN
# 484                                Matsuzawa,Yumi                  NaN
# 489                                         ["Bz"                  NaN
# 499                                           NaN                  NaN
#
#     ThemeSongComposition                                AnimationDirector  \
# 29          Oohara,Yuiko                                              NaN
# 61          Kajiura,Yuki                                              NaN
# 114        Mamiya,Michio                                 Kondou,Yoshifumi
# 117                  NaN                                              NaN
# 122                  NaN                                              NaN
# ..                   ...                                              ...
# 478                  NaN                                              NaN
# 479                  NaN                                              NaN
# 484         Yamada,Nobuo  Chino,Kyouko;Ishikawa,Shingo;Motohashi,Hideyuki
# 489                  NaN                                              NaN
# 499                  NaN                                   Kikuta,Kouichi
#
#         OriginalCreator                       ADRDirector ExecutiveProducer  \
# 29    RifujinnaMagonote                               NaN               NaN
# 61     Gotouge,Koyoharu                               NaN               NaN
# 114                 NaN                     Foster,Steven      Ledford,John
# 117                 NaN                               NaN               NaN
# 122    Akatsuki,Natsume                               NaN               NaN
# ..                  ...                               ...               ...
# 478  Nishimori,Hiroyuki                               NaN               NaN
# 479                 NaN                               NaN               NaN
# 484     Kurumada,Masami  Campos,Marcelo;Mullenaerts,Bruno               NaN
# 489        Aoyama,Gosho                               NaN               NaN
# 499    Akatsuki,Natsume                               NaN               NaN
#
#     ChiefAnimationDirector DirectorofPhotography  \
# 29                     NaN         Tonsho,Shinji
# 61                     NaN                   NaN
# 114                    NaN                   NaN
# 117        Takeuchi,Shinji                   NaN
# 122                    NaN                   NaN
# ..                     ...                   ...
# 478                    NaN                   NaN
# 479                    NaN                   NaN
# 484           Araki,Shingo                   NaN
# 489         Sudou,Masatomo                   NaN
# 499                    NaN                   NaN
#
#                                    In-BetweenAnimation  \
# 29                                                 NaN
# 61                                                 NaN
# 114  Isaka,Junko;Kamura,Hiroyuki;Shibata,Shirou;Tan...
# 117                                                NaN
# 122                                       Satou,Chieko
# ..                                                 ...
# 478                                                NaN
# 479                                                NaN
# 484                                                NaN
# 489                                                NaN
# 499                                                NaN
#
#                                          BackgroundArt           Planning  \
# 29                                                 NaN                NaN
# 61                                                 NaN                NaN
# 114  Hirata,Shuuichi;Hishiyama,Tooru;Nakaza,Youji;S...                NaN
# 117                                                NaN                NaN
# 122                                                NaN                NaN
# ..                                                 ...                ...
# 478                                                NaN                NaN
# 479                                                NaN                NaN
# 484                                                NaN  Sakurada,Hiroyuki
# 489                                                NaN     Suwa,Michihiko
# 499                                                NaN                NaN
#
#         ColorDesign AssistantAnimationDirector          Editing  \
# 29       Doi,Makiko                        NaN  Mishima,Akinori
# 61              NaN                        NaN              NaN
# 114  Yasuda,Michiyo           Momose,Yoshiyuki   Seyama,Takeshi
# 117             NaN                        NaN  Shiraishi,Akane
# 122             NaN                        NaN              NaN
# ..              ...                        ...              ...
# 478             NaN                        NaN              NaN
# 479             NaN                        NaN              NaN
# 484   Tsujita,Kunio                        NaN              NaN
# 489             NaN                        NaN              NaN
# 499             NaN                        NaN              NaN
#
#             ArtDirector              Music ProductionCoordination  \
# 29      Miyake,Masakazu  Fujisawa,Yoshiaki                    NaN
# 61                  NaN                NaN                    NaN
# 114      Yamamoto,Nizou      Mamiya,Michio                    NaN
# 117                 NaN                NaN                    NaN
# 122                 NaN       Kouda,Masato                    NaN
# ..                  ...                ...                    ...
# 478     Hashi,Katsuhiro                NaN                    NaN
# 479                 NaN                NaN                    NaN
# 484       Iijima,Yukiko     Yokoyama,Seiji                    NaN
# 489  Shibutani,Yukihiro         Ono,Katsuo                    NaN
# 499                 NaN                NaN                    NaN
#
#       DigitalPaint ColorSetting AssistantDirector       SoundEffects  \
# 29             NaN          NaN               NaN                NaN
# 61             NaN          NaN               NaN                NaN
# 114            NaN          NaN               NaN      Ito,Michihiro
# 117            NaN          NaN               NaN                NaN
# 122            NaN          NaN               NaN                NaN
# ..             ...          ...               ...                ...
# 478            NaN          NaN               NaN                NaN
# 479            NaN          NaN               NaN                NaN
# 484            NaN          NaN               NaN                NaN
# 489  Uemura,Takako          NaN               NaN  Yokoyama,Masakazu
# 499            NaN          NaN               NaN                NaN
#
#     InsertedSongPerformance OriginalCharacterDesign Setting     Screenplay  \
# 29                      NaN                     NaN     NaN            NaN
# 61                      NaN                     NaN     NaN            NaN
# 114                     NaN                     NaN     NaN  Takahata,Isao
# 117                     NaN                     NaN     NaN            NaN
# 122                     NaN          Mishima,Kurone     NaN            NaN
# ..                      ...                     ...     ...            ...
# 478                     NaN                     NaN     NaN            NaN
# 479                     NaN                     NaN     NaN            NaN
# 484                     NaN                     NaN     NaN            NaN
# 489         Takayama,Minami                     NaN     NaN            NaN
# 499                     NaN          Mishima,Kurone     NaN            NaN
#
#     AssociateProducer SpecialEffects AnimationCheck ProductionAssistant  \
# 29                NaN            NaN            NaN                 NaN
# 61                NaN            NaN            NaN                 NaN
# 114               NaN            NaN            NaN                 NaN
# 117               NaN            NaN            NaN                 NaN
# 122               NaN            NaN            NaN                 NaN
# ..                ...            ...            ...                 ...
# 478               NaN            NaN            NaN                 NaN
# 479               NaN            NaN            NaN                 NaN
# 484               NaN            NaN            NaN                 NaN
# 489               NaN            NaN            NaN                 NaN
# 499               NaN            NaN            NaN                 NaN
#
#     SoundSupervisor PrincipleDrawing AssistantProducer ProductionManager  \
# 29              NaN              NaN               NaN               NaN
# 61              NaN              NaN               NaN               NaN
# 114             NaN              NaN               NaN               NaN
# 117             NaN              NaN               NaN               NaN
# 122             NaN              NaN               NaN               NaN
# ..              ...              ...               ...               ...
# 478             NaN              NaN               NaN               NaN
# 479             NaN              NaN               NaN               NaN
# 484             NaN              NaN               NaN               NaN
# 489             NaN              NaN               NaN               NaN
# 499             NaN              NaN               NaN               NaN
#
#     SoundManager Co-Director SeriesProductionDirector MechanicalDesign  \
# 29           NaN         NaN                      NaN              NaN
# 61           NaN         NaN                      NaN              NaN
# 114          NaN         NaN                      NaN              NaN
# 117          NaN         NaN                      NaN              NaN
# 122          NaN         NaN                      NaN              NaN
# ..           ...         ...                      ...              ...
# 478          NaN         NaN                      NaN              NaN
# 479          NaN         NaN                      NaN              NaN
# 484          NaN         NaN                      NaN              NaN
# 489          NaN         NaN                      NaN              NaN
# 499          NaN         NaN                      NaN              NaN
#
#     PlanningProducer            Layout ChiefProducer Recording  \
# 29               NaN               NaN           NaN       NaN
# 61               NaN               NaN           NaN       NaN
# 114              NaN  Momose,Yoshiyuki           NaN       NaN
# 117              NaN               NaN           NaN       NaN
# 122              NaN               NaN           NaN       NaN
# ..               ...               ...           ...       ...
# 478              NaN               NaN           NaN       NaN
# 479              NaN               NaN           NaN       NaN
# 484              NaN               NaN           NaN       NaN
# 489              NaN               NaN           NaN       NaN
# 499              NaN               NaN           NaN       NaN
#
#     DialogueEditing RecordingEngineer Creator RecordingAssistant Publicity  \
# 29              NaN               NaN     NaN                NaN       NaN
# 61              NaN               NaN     NaN                NaN       NaN
# 114             NaN               NaN     NaN                NaN       NaN
# 117             NaN               NaN     NaN                NaN       NaN
# 122             NaN               NaN     NaN                NaN       NaN
# ..              ...               ...     ...                ...       ...
# 478             NaN               NaN     NaN                NaN       NaN
# 479             NaN               NaN     NaN                NaN       NaN
# 484             NaN               NaN     NaN                NaN       NaN
# 489             NaN               NaN     NaN                NaN       NaN
# 499             NaN               NaN     NaN                NaN       NaN
#
#     Co-Producer CastingDirector Re-RecordingMixing  \
# 29          NaN             NaN                NaN
# 61          NaN             NaN                NaN
# 114         NaN             NaN                NaN
# 117         NaN             NaN                NaN
# 122         NaN             NaN                NaN
# ..          ...             ...                ...
# 478         NaN             NaN                NaN
# 479         NaN             NaN                NaN
# 484         NaN             NaN                NaN
# 489         NaN             NaN                NaN
# 499         NaN             NaN                NaN
#
#     AssistantProductionCoordinat SettingManager
# 29                           NaN            NaN
# 61                           NaN            NaN
# 114                          NaN            NaN
# 117                          NaN            NaN
# 122                          NaN            NaN
# ..                           ...            ...
# 478                          NaN            NaN
# 479                          NaN            NaN
# 484                          NaN            NaN
# 489                          NaN            NaN
# 499                          NaN            NaN
#
# [64 rows x 90 columns]

# %%
# Vamos substituir "Nonefound" por nan para a próxima análise
df[df["producers"].str.contains("Nonefound")] = np.nan

# %% [markdown]
# ## 9- Quantos vezes cada produtor participou da produção de um anime?

# %%
df.head()
# Out:
#    ranking                                name  \
# 0      1.0    Fullmetal Alchemist: Brotherhood
# 1      2.0                            Gintama°
# 2      3.0  Shingeki no Kyojin Season 3 Part 2
# 3      4.0                         Steins;Gate
# 4      5.0            Fruits Basket: The Final
#
#                                            producers  votersCount  score  \
# 0  Aniplex;SquareEnix;MainichiBroadcastingSystem;...    1650275.0   9.15
# 1                             TVTokyo;Aniplex;Dentsu     173906.0   9.09
# 2  ProductionI.G;Dentsu;MainichiBroadcastingSyste...    1127900.0   9.09
# 3  FrontierWorks;MediaFactory;Movic;AT-X;Kadokawa...    1128557.0   9.09
# 4  TVTokyo;TVOsaka;NihonAdSystems;Hakusensha;Avex...     124091.0   9.06
#
#    popularity    members  favorite  episodes animeType premiredDate  \
# 0         3.0  2713695.0  191501.0      64.0        TV  Spring 2009
# 1       337.0   493336.0   13063.0      51.0        TV  Spring 2015
# 2        33.0  1635976.0   46238.0      10.0        TV  Spring 2019
# 3        12.0  2117018.0  162324.0      24.0        TV  Spring 2011
# 4       619.0   288314.0   13330.0      13.0        TV  Spring 2021
#
#     animeSource                                         genres  \
# 0         Manga          Action;Adventure;Comedy;Drama;Fantasy
# 1         Manga                           Action;Comedy;Sci-fi
# 2         Manga                   Action;Drama;Fantasy;Mystery
# 3  Visual novel                          Drama;Sci-fi;Suspense
# 4         Manga  Comedy;Drama;Romance;Sliceoflife;Supernatural
#
#                  studios                     licenses       rating  \
# 0                  Bones  Funimation;AniplexofAmerica        R-17+
# 1  Bandai Namco Pictures       Funimation;Crunchyroll  PG-13-Teens
# 2             Wit Studio                   Funimation        R-17+
# 3              White Fox                   Funimation  PG-13-Teens
# 4      TMS Entertainment                   Funimation  PG-13-Teens
#
#                                             Japanese  \
# 0  Kugimiya,Rie;Park,Romi;Utsumi,Kenji;Utsumi,Ken...
# 1  Kugimiya,Rie;Ishii,Kouji;Sugita,Tomokazu;Tomat...
# 2  Ishikawa,Yui;Inoue,Marina;Kamiya,Hiroshi;Kaji,...
# 3  Seki,Tomokazu;Imai,Asami;Miyano,Mamoru;Hanazaw...
# 4  Iwami,Manaka;Uchida,Yuuma;Shimazaki,Nobunaga;S...
#
#                                              Italian  \
# 0  Ponticelli,Benedetta;Novara,Renato;Scianca,Pat...
# 1                                                NaN
# 2  Perino,Elena;Bolognesi,Gaia;Raffaeli,Daniele;C...
# 3  Vivio,Paolo;Paolelli,Rachele;Chevalier,Davide;...
# 4                                                NaN
#
#                                       Portuguese(BR)  \
# 0  Andreatto,Rodrigo;Campos,Marcelo;Zink,Mariana;...
# 1                                                NaN
# 2  Stefane,Mayara;Volpato,Pedro;Sangregório,Bruno...
# 3  Casemiro,Bruno;Cunha,Maitê;Rinaldi,André;Lua,B...
# 4  Ruis,Carolina;Campos,Fábio;Volpato,Pedro;Caval...
#
#                                               German  \
# 0  Gerick,Wanja;Turba,David;Häcke,Maximiliane;Mai...
# 1                                                NaN
# 2                                                NaN
# 3  Wirthgen,Jesco;Bäcker,Manuela;Gavrilis,Marios;...
# 4                                                NaN
#
#                                            Hungarian  \
# 0  Baráth,István;Szabó,Máté;Faragó,András;Varga,R...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              English  \
# 0  Whitehead,Maxey;Truncale,Lily;Mignogna,Vic;Hof...
# 1  Loewen,Jocelyne;Daingerfield,Michael;Pitre,Sab...
# 2  Nishimura,Trina;Grelle,Josh;Mercer,Matthew;Pap...
# 3  Rinehart,Tyson;Nishimura,Trina;Tatum,JohnMicha...
# 4        Yeung,Suzie;Sabat,Christopher;Leigh,Cherami
#
#                                               Korean  \
# 0  Yun,MiNa;O,InSeong;Yang,JeongHwa;Lee,JiYeong;H...
# 1                                                NaN
# 2                                                NaN
# 3  Wu,JeongSin;Hong,SiHo;Yeo,MinJeong;Kim,SeoYeon...
# 4                                                NaN
#
#                                              Spanish  \
# 0  Torres,Jhonny;Vieira,JoseManuel;Perez,LuisMigu...
# 1                                                NaN
# 2                                                NaN
# 3                                         Naro,Jordi
# 4                                                NaN
#
#                                               French Mandarin Hebrew  \
# 0  Pic,Audrey;Boudonnat,Lucille;Pestel,Arthur;Cre...      NaN    NaN
# 1                                                NaN      NaN    NaN
# 2  Bienaimé,Nathalie;Niverd,Victor;Méyère,Bruno;G...      NaN    NaN
# 3  Pasquier,Laurent;Cornibert,Sarah;Wilhelm,Marc;...      NaN    NaN
# 4                                                NaN      NaN    NaN
#
#                                             Producer  \
# 0                         Cook,Justin;Yonai,Noritomo
# 1                                                NaN
# 2  Morishita,Katsuji;Nakatake,Tetsuya;Wada,Jouji;...
# 3                          Iwasa,Gaku;Yasuda,Takeshi
# 4                                                NaN
#
#                           Director  \
# 0                    Irie,Yasuhiro
# 1  Fujita,Youichi;Miyawaki,Chizuru
# 2   Araki,Tetsurou;Koizuka,Masashi
# 3    Hamasaki,Hiroshi;Satou,Takuya
# 4                  Ibata,Yoshihide
#
#                                      EpisodeDirector  \
# 0  Irie,Yasuhiro;Ikehata,Hiroshi;Ikezoe,Takahiro;...
# 1  Asami,Matsuo;Koshida,Tomoaki;Minami,Yasuhiro;M...
# 2  Araki,Tetsurou;Itoga,Shintaro;Tanaka,Hiroyuki;...
# 3  Hamasaki,Hiroshi;Satou,Takuya;Kobayashi,Kouji;...
# 4                                                NaN
#
#                                           Storyboard      SoundDirector  \
# 0  Irie,Yasuhiro;Ikezoe,Takahiro;Kinutani,Soushi;...      Mima,Masafumi
# 1    Fujita,Youichi;Miyawaki,Chizuru;Minami,Yasuhiro   Takamatsu,Shinji
# 2  Araki,Tetsurou;Akamatsu,Yasuhiro;Komatsuda,Dai...      Mima,Masafumi
# 3  Hamasaki,Hiroshi;Satou,Takuya;Kobayashi,Tomoki...  Fujiyama,Fusanobu
# 4                                                NaN      Aketagawa,Jin
#
#                                         KeyAnimation  \
# 0  Ikezoe,Takahiro;Kinutani,Soushi;Morii,Kenshiro...
# 1  Miyawaki,Chizuru;Abe,Miyuki;Hayashi,Kanako;Hay...
# 2   Imai,Arifumi;Izawa,Tamami;Oota,Emi;Yamauchi,Ryou
# 3  Hamasaki,Hiroshi;Aono,Atsushi;Arai,Nobuhiro;Hi...
# 4                                                NaN
#
#                                      2ndKeyAnimation  \
# 0  Ikezoe,Takahiro;Akasaka,Shunji;Kameda,Yoshimic...
# 1     Hayashi,Kanako;Honjou,Keiichirou;Sasaki,Youhei
# 2                                                NaN
# 3                      Hamaguchi,Akira;Satou,Hiroaki
# 4                                                NaN
#
#                 CharacterDesign  \
# 0  Morii,Kenshirou;Kanno,Hiroki
# 1               Takeuchi,Shinji
# 2                  Asano,Kyouji
# 3                  Sakai,Kyuuta
# 4                   Shindou,Yuu
#
#                                               Script SeriesComposition  \
# 0  Burgmeier,John;Minakami,Seishi;Oonogi,Hiroshi;...    Oonogi,Hiroshi
# 1         Kishimoto,Taku;Matsubara,Shuu;Mieno,Hitomi               NaN
# 2                      Kobayashi,Yasuko;Seko,Hiroshi  Kobayashi,Yasuko
# 3  Hanada,Jukki;Nemoto,Toshizou;Tatum,JohnMichael...      Hanada,Jukki
# 4                                                NaN    Kishimoto,Taku
#
#                                      ThemeSongLyrics  \
# 0  CHEMISTRY;NICOTouchestheWalls;SCANDAL;SID;Suki...
# 1              AquaTimez;BLUEENCOUNT;DOES;HoneyWorks
# 2                                                NaN
# 3                                  Shikura,Chiyomaru
# 4                                                NaN
#
#                                 ThemeSongPerformance  \
# 0  CHEMISTRY;Fukuhara,Miho;["LilB";NICOTouchesthe...
# 1  AquaTimez;BLUEENCOUNT;CHiCO;DOES;HoneyWorks;Ne...
# 2                          CinemaStaff;LinkedHorizon
# 3                         Itou,Kanako;Sakakibara,Yui
# 4                                      GENIC;WARPsUP
#
#                                 ThemeSongArrangement  \
# 0  Kameda,Seiji;NICOTouchestheWalls;SID;SukimaSwitch
# 1        AquaTimez;BLUEENCOUNT;DOES;HoneyWorks;Swimy
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                        ThemeSongComposition  \
# 0  NICOTouchestheWalls;SID;SukimaSwitch;Yui
# 1     AquaTimez;BLUEENCOUNT;DOES;HoneyWorks
# 2                                       NaN
# 3                         Shikura,Chiyomaru
# 4                                       NaN
#
#                                    AnimationDirector  \
# 0  Aono,Atsushi;Iijima,Hiroya;Ishino,Satoshi;Koba...
# 1  Honjou,Keiichirou;Ikeuchi,Naoko;Ishikawa,Marik...
# 2  Koizuka,Masashi;Chiba,Takaaki;Ebisu,Takuma;Has...
# 3  Aono,Atsushi;Arai,Nobuhiro;Igari,Takashi;Ikega...
# 4                                                NaN
#
#                     OriginalCreator  \
# 0                    Arakawa,Hiromu
# 1                   Sorachi,Hideaki
# 2                    Isayama,Hajime
# 3  Shikura,Chiyomaru;5pb.;Nitroplus
# 4                    Takaya,Natsuki
#
#                                          ADRDirector   ExecutiveProducer  \
# 0  Bezerra,Úrsula;Campos,Marcelo;Glass,Caitlin;Ka...        Fukunaga,Gen
# 1                                                NaN                 NaN
# 2                                  Sangregório,Bruno  Ishikawa,Mitsuhisa
# 3                 Clinkenbeard,Colleen;Rinaldi,André        Fukunaga,Gen
# 4                                       Falcão,Jonas                 NaN
#
#                             ChiefAnimationDirector     DirectorofPhotography  \
# 0  Fukuoka,Hidenori;Kameda,Yoshimichi;Kaneda,Naomi           Furumoto,Mayuko
# 1                                              NaN            Teramoto,Yuuki
# 2                    Asano,Kyouji;Kadowaki,Satoshi           Yamada,Kazuhiro
# 3                                     Sakai,Kyuuta          Nakamura,Keisuke
# 4                                              NaN  Cai,Bolun;Shitara,Nozomi
#
#                                  In-BetweenAnimation  \
# 0  Kameda,Yoshimichi;Oosawa,Mina;Saitou,Kengo;Yok...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        BackgroundArt  \
# 0  Kanehira,Kazushige;Nakajima,Mika;Ooizumi,Anna;...
# 1                                                NaN
# 2                                      Fujii,Kazushi
# 3  Kanehira,Kazushige;Kouji,Etou;Maeda,Yuki;Nemot...
# 4                                        Fujii,Yuuta
#
#                            Planning        ColorDesign  \
# 0        Minami,Masahiko;Ueda,Masuo       Nakao,Fusako
# 1                    Fujita,Youichi    Utagawa,Ritsuko
# 2                 Morishita,Katsuji  Hashimoto,Satoshi
# 3  Yasuda,Takeshi;Shikura,Chiyomaru       Satou,Miyuki
# 4                               NaN      Sugawara,Mika
#
#                           AssistantAnimationDirector         Editing  \
# 0                     Park,Seong-Hu;Yoshioka,Takeshi   Sadamatsu,Gou
# 1                                      Nakamura,Yumi  Seyama,Takeshi
# 2                                                NaN        Hida,Aya
# 3  Ikegami,Tarou;Nakamura,Kazuhisa;Sakai,Kyuuta;Y...             NaN
# 4                                                NaN        Hida,Aya
#
#                        ArtDirector            Music ProductionCoordination  \
# 0                    Satou,Takeshi      Senju,Akira             Shinya,Une
# 1  Fukushima,Takayoshi;Maniwa,Nami       AudioHighs                    NaN
# 2            Yoshihara,Shunichirou  Sawano,Hiroyuki                    NaN
# 3                       Kouji,Etou      Abo,Takeshi                    NaN
# 4                   Kamiyama,Youko  Yokoyama,Masaru                    NaN
#
#     DigitalPaint     ColorSetting                AssistantDirector  \
# 0  Uemura,Takako              NaN                              NaN
# 1            NaN  Utagawa,Ritsuko                              NaN
# 2            NaN              NaN  Koizuka,Masashi;Tanaka,Hiroyuki
# 3            NaN              NaN                              NaN
# 4            NaN              NaN                              NaN
#
#        SoundEffects InsertedSongPerformance OriginalCharacterDesign Setting  \
# 0               NaN                     NaN                     NaN     NaN
# 1               NaN                     NaN                     NaN     NaN
# 2  Kurahashi,Shizuo                     NaN                     NaN     NaN
# 3               NaN          JunjounoAfilia                    huke     NaN
# 4               NaN                     NaN                     NaN     NaN
#
#   Screenplay AssociateProducer SpecialEffects AnimationCheck  \
# 0        NaN               NaN            NaN            NaN
# 1        NaN               NaN            NaN            NaN
# 2        NaN               NaN            NaN            NaN
# 3        NaN               NaN            NaN            NaN
# 4        NaN               NaN            NaN            NaN
#
#   ProductionAssistant SoundSupervisor PrincipleDrawing AssistantProducer  \
# 0                 NaN             NaN              NaN               NaN
# 1                 NaN             NaN              NaN               NaN
# 2                 NaN             NaN              NaN               NaN
# 3                 NaN             NaN              NaN               NaN
# 4                 NaN             NaN              NaN               NaN
#
#   ProductionManager SoundManager Co-Director SeriesProductionDirector  \
# 0               NaN          NaN         NaN                      NaN
# 1               NaN          NaN         NaN                      NaN
# 2               NaN          NaN         NaN                      NaN
# 3               NaN          NaN         NaN                      NaN
# 4               NaN          NaN         NaN                      NaN
#
#   MechanicalDesign PlanningProducer Layout ChiefProducer Recording  \
# 0              NaN              NaN    NaN           NaN       NaN
# 1              NaN              NaN    NaN           NaN       NaN
# 2              NaN              NaN    NaN           NaN       NaN
# 3              NaN              NaN    NaN           NaN       NaN
# 4              NaN              NaN    NaN           NaN       NaN
#
#   DialogueEditing RecordingEngineer Creator RecordingAssistant Publicity  \
# 0             NaN               NaN     NaN                NaN       NaN
# 1             NaN               NaN     NaN                NaN       NaN
# 2             NaN               NaN     NaN                NaN       NaN
# 3             NaN               NaN     NaN                NaN       NaN
# 4             NaN               NaN     NaN                NaN       NaN
#
#   Co-Producer CastingDirector Re-RecordingMixing AssistantProductionCoordinat  \
# 0         NaN             NaN                NaN                          NaN
# 1         NaN             NaN                NaN                          NaN
# 2         NaN             NaN                NaN                          NaN
# 3         NaN             NaN                NaN                          NaN
# 4         NaN             NaN                NaN                          NaN
#
#   SettingManager
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
unique_producers = []

# %%
# Extrai os producers únicos
for data in df["producers"]:
    if type(data) != float:
        new_data = data.split(";")
        for producer in new_data:
            if producer not in unique_producers:
                unique_producers.append(producer)

# %%
unique_producers
# Out:
# ['Aniplex',
#  'SquareEnix',
#  'MainichiBroadcastingSystem',
#  'StudioMoriken',
#  'TVTokyo',
#  'Dentsu',
#  'ProductionI.G',
#  'PonyCanyon',
#  'Kodansha',
#  'TechnoSound',
#  'PonyCanyonEnterprise',
#  'FrontierWorks',
#  'MediaFactory',
#  'Movic',
#  'AT-X',
#  'KadokawaPicturesJapan',
#  'Nitroplus',
#  'TVOsaka',
#  'NihonAdSystems',
#  'Hakusensha',
#  'AvexPictures',
#  'TMSMusic',
#  'TrinitySound',
#  'MiracleRobo',
#  'StudioJack',
#  'Shueisha',
#  'VAP',
#  'NipponTelevisionNetwork',
#  'KittyFilms',
#  'TokumaShoten',
#  'TokumaJapanCommunications',
#  'MiracleBus',
#  'WarnerBros.Japan',
#  'Shochiku',
#  'NHK',
#  'AsmikAce',
#  '"ToysFactory"',
#  'ABCAnimation',
#  'Quaras',
#  'TBS',
#  'Rakuonsha',
#  'AnimationDo',
#  'AudioHighs',
#  'Bandai',
#  'BandaiVisual',
#  'BandaiNamcoEntertainment',
#  'HakuhodoDYMediaPartners',
#  'Toho',
#  'SoundTeamDonJuan',
#  'Amuse',
#  'JREastMarketing&Communications',
#  'Kadokawa',
#  'voqueting',
#  'FujiTV',
#  'bilibili',
#  'BeDream',
#  'SonyMusicEntertainment',
#  'TOHOanimation',
#  'KlockWorx',
#  'BSFuji',
#  'HakuhodoDYMusic&Pictures',
#  'Shogakukan',
#  'Shogakukan-ShueishaProductions',
#  'CycloneGraphics',
#  'DAXProduction',
#  'KingRecords',
#  'DelfiSound',
#  'Notes',
#  'TencentPenguinPictures',
#  'TwinEngine',
#  'dugout',
#  'Sumzap',
#  'Annapuru',
#  'Takeshobo',
#  'SonyMusicCommunications',
#  'KadokawaMediaHouse',
#  'Cygames',
#  'KanetsuInvestment',
#  'GlobalSolutions',
#  'IRMALADOUCE',
#  'AvexEntertainment',
#  'Marvelous',
#  'SKYPerfectWellThink',
#  'KyorakuIndustrialHoldings',
#  'd-rights',
#  'Lantis',
#  'TokyoMX',
#  'NagoyaBroadcastingNetwork',
#  'BS11',
#  'Konami',
#  'HalfH.PStudio',
#  'KadokawaShoten',
#  'AshiProduction',
#  'ScienceSARU',
#  'TAP',
#  'Madhouse',
#  'YomiuriTelecasting',
#  'HiroshimaTelevision',
#  'MedicosEntertainment',
#  'StarchildRecords',
#  'SakuraCreate',
#  'TohokushinshaFilmCorporation',
#  'FujipacificMusic',
#  'Seikaisha',
#  'CA-CygamesAnimeFund',
#  'BandaiSpirits',
#  'DocomoAnimeStore',
#  'NewGin',
#  'CrunchyrollSCAnimeFund',
#  'ToeiAnimation',
#  'Sega',
#  'TVTokyoMusic',
#  'AudioTanaka',
#  'MAGES.',
#  'DeNA',
#  'VictorEntertainment',
#  'TVAsahi',
#  'Animax',
#  'AsatsuDK',
#  'Banpresto',
#  'GoodSmileCompany',
#  'MadBox',
#  'StudioHibari',
#  'KansaiTelecasting',
#  'Sonilude',
#  'RexEntertainment',
#  'YTV',
#  'BarnumStudio',
#  'flyingDOG',
#  'MagGarden',
#  'TCEntertainment',
#  'NipponTelevisionMusic',
#  'FBC',
#  'SpaceyMusicEntertainment',
#  'Houbunsha',
#  'MagicCapsule',
#  'NBCUniversalEntertainmentJapan',
#  'HeartCompany',
#  'YomikoAdvertising',
#  'NipponColumbia',
#  'DearStageinc.',
#  'SharefunStudio',
#  'AHAEntertainment',
#  'KamikazeDouga',
#  'NHKEnterprises',
#  'Q-Tec',
#  'GYAO!',
#  'TrilogyFutureStudio',
#  'Showgate',
#  'Shout!Factory',
#  'WOWOW',
#  'Memory-Tech',
#  'YomiuriShimbun',
#  'MediaLinkEntertainmentLimited',
#  'BandaiNamcoArts',
#  'Bitgrooovepromotion',
#  'SonyMusicSolutions',
#  'NAZ',
#  'HappinetPictures',
#  'ReddogCultureHouse',
#  'Sunrise',
#  'GeneonUniversalEntertainment',
#  'StudioRFInc.',
#  'ShounenGahousha',
#  'ForecastCommunications',
#  'EggFirm',
#  'GREE',
#  'TohoMusic',
#  'OLM',
#  'BandaiNamcoGames',
#  'VoyagerEntertainment',
#  'Shinshokan',
#  'Sotsu',
#  'D.N.DreamPartners',
#  'Imagin',
#  'LawsonHMVEntertainment',
#  'STORY',
#  'LawsonEntertainment',
#  'Gainax',
#  'Lawson',
#  'C-one',
#  'Infinite',
#  'Imagine',
#  'MicroMagazinePublishing',
#  'ADKMarketingSolutions',
#  'OBPlanning',
#  'Genco',
#  'StudioWombat',
#  'chara-ani.com',
#  'ASCIIMediaWorks',
#  'SMEVisualWorks',
#  'Arquebuse',
#  'Toranoana',
#  '81Produce',
#  'StudioFantasia',
#  'FuRyu',
#  'AsahiBroadcasting',
#  'AbeShuujiJimusho',
#  'ShizuokaAsahiTelevision',
#  'KadokawaAnimation',
#  'KinoshitaGroupHoldings',
#  'MarvelousAQL',
#  'BMGJapan',
#  'KidsStation',
#  'YomiuriTVEnterprise',
#  'TMSEntertainment',
#  'Sammy',
#  'AnimatsuEntertainment',
#  'KSS',
#  'comico',
#  'BandaiNamcoLiveCreative',
#  'Glovision',
#  'MyTheaterD.D.',
#  'Mirai-Kojo',
#  'Animatic',
#  'Yahoo!Japan',
#  'BeyondC.',
#  'RialtoEntertainment',
#  'SonyPCL',
#  'Shelty',
#  'AmberFilmWorks',
#  'IWill',
#  'Bushiroad',
#  'Kinyosha',
#  'Shinchosha',
#  'Graphinica',
#  'FrontLine',
#  'AiAddiction',
#  'A-Sketch',
#  'Akatsuki',
#  'TMS-Kyokuchi',
#  'GDH',
#  'SotsuMusicPublishing',
#  'SogoVision',
#  'WarnerMusicJapan',
#  'Nichion',
#  'GoodSmileFilm',
#  'MAGNET',
#  'EMI',
#  'YomiuriAdvertising',
#  'MediaNet',
#  'Happinet',
#  'TokyoAnimatorGakuin',
#  'TOBooks',
#  'JTBNextCreation',
#  'Echoes',
#  'GANSIS',
#  'KBS',
#  'DMM.com',
#  'AkitaShoten',
#  'RobotCommunications',
#  'AgeGlobalNetworks',
#  'CBCTelevision',
#  'VisualArts',
#  'MyricaMusic',
#  'DreamForce',
#  'Sumitomo',
#  'RAY',
#  'Pia',
#  'TokyoMovieShinsha',
#  'WaltDisneyStudios',
#  'J.C.Staff',
#  'TokumaJapan',
#  'NTTDocomo',
#  'BandaiChannel',
#  'USEN',
#  'UltraSuperPictures',
#  'LucentPicturesEntertainment',
#  'PioneerLDC',
#  'SonyPicturesEntertainment',
#  '5pb.',
#  'HoriProInternational',
#  'Cloud22',
#  'Directions',
#  'Code',
#  'TrickBlock',
#  'Delightworks',
#  'TatsunokoProduction',
#  'Imagica']

# %%
# Cria um dicionário
prod_dic = dict()

# %%
# Inicializa o dicionário com zero
for i in unique_producers:
    prod_dic[i] = 0

# %%
# Agrega os produtores
for prod in unique_producers:
    for i in range(0, len(df["producers"])):
        if type(df["producers"][i]) != float and (df["producers"][i].__contains__(prod)) == True:
            prod_dic[prod] += 1

# %%
prod_dic
# Out:
# {'Aniplex': 100,
#  'SquareEnix': 9,
#  'MainichiBroadcastingSystem': 48,
#  'StudioMoriken': 1,
#  'TVTokyo': 53,
#  'Dentsu': 70,
#  'ProductionI.G': 13,
#  'PonyCanyon': 29,
#  'Kodansha': 52,
#  'TechnoSound': 4,
#  'PonyCanyonEnterprise': 7,
#  'FrontierWorks': 11,
#  'MediaFactory': 12,
#  'Movic': 48,
#  'AT-X': 18,
#  'KadokawaPicturesJapan': 6,
#  'Nitroplus': 9,
#  'TVOsaka': 3,
#  'NihonAdSystems': 16,
#  'Hakusensha': 15,
#  'AvexPictures': 8,
#  'TMSMusic': 5,
#  'TrinitySound': 4,
#  'MiracleRobo': 3,
#  'StudioJack': 2,
#  'Shueisha': 68,
#  'VAP': 22,
#  'NipponTelevisionNetwork': 29,
#  'KittyFilms': 4,
#  'TokumaShoten': 11,
#  'TokumaJapanCommunications': 2,
#  'MiracleBus': 1,
#  'WarnerBros.Japan': 17,
#  'Shochiku': 16,
#  'NHK': 24,
#  'AsmikAce': 8,
#  '"ToysFactory"': 6,
#  'ABCAnimation': 6,
#  'Quaras': 1,
#  'TBS': 7,
#  'Rakuonsha': 11,
#  'AnimationDo': 7,
#  'AudioHighs': 2,
#  'Bandai': 44,
#  'BandaiVisual': 27,
#  'BandaiNamcoEntertainment': 5,
#  'HakuhodoDYMediaPartners': 6,
#  'Toho': 21,
#  'SoundTeamDonJuan': 1,
#  'Amuse': 1,
#  'JREastMarketing&Communications': 8,
#  'Kadokawa': 51,
#  'voqueting': 2,
#  'FujiTV': 40,
#  'bilibili': 3,
#  'BeDream': 1,
#  'SonyMusicEntertainment': 25,
#  'TOHOanimation': 18,
#  'KlockWorx': 24,
#  'BSFuji': 6,
#  'HakuhodoDYMusic&Pictures': 10,
#  'Shogakukan': 20,
#  'Shogakukan-ShueishaProductions': 9,
#  'CycloneGraphics': 2,
#  'DAXProduction': 12,
#  'KingRecords': 3,
#  'DelfiSound': 7,
#  'Notes': 12,
#  'TencentPenguinPictures': 6,
#  'TwinEngine': 4,
#  'dugout': 1,
#  'Sumzap': 1,
#  'Annapuru': 1,
#  'Takeshobo': 1,
#  'SonyMusicCommunications': 7,
#  'KadokawaMediaHouse': 10,
#  'Cygames': 5,
#  'KanetsuInvestment': 2,
#  'GlobalSolutions': 2,
#  'IRMALADOUCE': 4,
#  'AvexEntertainment': 4,
#  'Marvelous': 6,
#  'SKYPerfectWellThink': 1,
#  'KyorakuIndustrialHoldings': 8,
#  'd-rights': 2,
#  'Lantis': 29,
#  'TokyoMX': 5,
#  'NagoyaBroadcastingNetwork': 3,
#  'BS11': 12,
#  'Konami': 2,
#  'HalfH.PStudio': 6,
#  'KadokawaShoten': 20,
#  'AshiProduction': 2,
#  'ScienceSARU': 1,
#  'TAP': 1,
#  'Madhouse': 1,
#  'YomiuriTelecasting': 7,
#  'HiroshimaTelevision': 1,
#  'MedicosEntertainment': 2,
#  'StarchildRecords': 4,
#  'SakuraCreate': 5,
#  'TohokushinshaFilmCorporation': 7,
#  'FujipacificMusic': 6,
#  'Seikaisha': 2,
#  'CA-CygamesAnimeFund': 1,
#  'BandaiSpirits': 5,
#  'DocomoAnimeStore': 3,
#  'NewGin': 1,
#  'CrunchyrollSCAnimeFund': 2,
#  'ToeiAnimation': 2,
#  'Sega': 1,
#  'TVTokyoMusic': 6,
#  'AudioTanaka': 3,
#  'MAGES.': 4,
#  'DeNA': 3,
#  'VictorEntertainment': 7,
#  'TVAsahi': 7,
#  'Animax': 6,
#  'AsatsuDK': 4,
#  'Banpresto': 4,
#  'GoodSmileCompany': 6,
#  'MadBox': 1,
#  'StudioHibari': 3,
#  'KansaiTelecasting': 2,
#  'Sonilude': 1,
#  'RexEntertainment': 1,
#  'YTV': 5,
#  'BarnumStudio': 1,
#  'flyingDOG': 8,
#  'MagGarden': 3,
#  'TCEntertainment': 1,
#  'NipponTelevisionMusic': 1,
#  'FBC': 1,
#  'SpaceyMusicEntertainment': 1,
#  'Houbunsha': 5,
#  'MagicCapsule': 9,
#  'NBCUniversalEntertainmentJapan': 6,
#  'HeartCompany': 1,
#  'YomikoAdvertising': 3,
#  'NipponColumbia': 5,
#  'DearStageinc.': 2,
#  'SharefunStudio': 2,
#  'AHAEntertainment': 2,
#  'KamikazeDouga': 2,
#  'NHKEnterprises': 4,
#  'Q-Tec': 3,
#  'GYAO!': 3,
#  'TrilogyFutureStudio': 1,
#  'Showgate': 6,
#  'Shout!Factory': 1,
#  'WOWOW': 7,
#  'Memory-Tech': 7,
#  'YomiuriShimbun': 1,
#  'MediaLinkEntertainmentLimited': 1,
#  'BandaiNamcoArts': 7,
#  'Bitgrooovepromotion': 1,
#  'SonyMusicSolutions': 2,
#  'NAZ': 1,
#  'HappinetPictures': 4,
#  'ReddogCultureHouse': 1,
#  'Sunrise': 1,
#  'GeneonUniversalEntertainment': 6,
#  'StudioRFInc.': 1,
#  'ShounenGahousha': 1,
#  'ForecastCommunications': 1,
#  'EggFirm': 1,
#  'GREE': 1,
#  'TohoMusic': 3,
#  'OLM': 1,
#  'BandaiNamcoGames': 4,
#  'VoyagerEntertainment': 1,
#  'Shinshokan': 1,
#  'Sotsu': 14,
#  'D.N.DreamPartners': 1,
#  'Imagin': 3,
#  'LawsonHMVEntertainment': 2,
#  'STORY': 1,
#  'LawsonEntertainment': 1,
#  'Gainax': 1,
#  'Lawson': 4,
#  'C-one': 1,
#  'Infinite': 1,
#  'Imagine': 2,
#  'MicroMagazinePublishing': 2,
#  'ADKMarketingSolutions': 1,
#  'OBPlanning': 3,
#  'Genco': 10,
#  'StudioWombat': 1,
#  'chara-ani.com': 2,
#  'ASCIIMediaWorks': 4,
#  'SMEVisualWorks': 1,
#  'Arquebuse': 1,
#  'Toranoana': 2,
#  '81Produce': 3,
#  'StudioFantasia': 1,
#  'FuRyu': 1,
#  'AsahiBroadcasting': 1,
#  'AbeShuujiJimusho': 1,
#  'ShizuokaAsahiTelevision': 1,
#  'KadokawaAnimation': 1,
#  'KinoshitaGroupHoldings': 1,
#  'MarvelousAQL': 2,
#  'BMGJapan': 1,
#  'KidsStation': 1,
#  'YomiuriTVEnterprise': 4,
#  'TMSEntertainment': 4,
#  'Sammy': 1,
#  'AnimatsuEntertainment': 1,
#  'KSS': 1,
#  'comico': 1,
#  'BandaiNamcoLiveCreative': 2,
#  'Glovision': 2,
#  'MyTheaterD.D.': 1,
#  'Mirai-Kojo': 1,
#  'Animatic': 1,
#  'Yahoo!Japan': 1,
#  'BeyondC.': 2,
#  'RialtoEntertainment': 1,
#  'SonyPCL': 1,
#  'Shelty': 1,
#  'AmberFilmWorks': 1,
#  'IWill': 1,
#  'Bushiroad': 2,
#  'Kinyosha': 1,
#  'Shinchosha': 1,
#  'Graphinica': 1,
#  'FrontLine': 1,
#  'AiAddiction': 1,
#  'A-Sketch': 1,
#  'Akatsuki': 1,
#  'TMS-Kyokuchi': 1,
#  'GDH': 1,
#  'SotsuMusicPublishing': 1,
#  'SogoVision': 2,
#  'WarnerMusicJapan': 1,
#  'Nichion': 2,
#  'GoodSmileFilm': 2,
#  'MAGNET': 1,
#  'EMI': 1,
#  'YomiuriAdvertising': 1,
#  'MediaNet': 2,
#  'Happinet': 5,
#  'TokyoAnimatorGakuin': 1,
#  'TOBooks': 1,
#  'JTBNextCreation': 1,
#  'Echoes': 1,
#  'GANSIS': 1,
#  'KBS': 1,
#  'DMM.com': 1,
#  'AkitaShoten': 1,
#  'RobotCommunications': 1,
#  'AgeGlobalNetworks': 1,
#  'CBCTelevision': 1,
#  'VisualArts': 1,
#  'MyricaMusic': 1,
#  'DreamForce': 1,
#  'Sumitomo': 2,
#  'RAY': 1,
#  'Pia': 1,
#  'TokyoMovieShinsha': 1,
#  'WaltDisneyStudios': 1,
#  'J.C.Staff': 1,
#  'TokumaJapan': 3,
#  'NTTDocomo': 1,
#  'BandaiChannel': 1,
#  'USEN': 1,
#  'UltraSuperPictures': 2,
#  'LucentPicturesEntertainment': 1,
#  'PioneerLDC': 1,
#  'SonyPicturesEntertainment': 1,
#  '5pb.': 1,
#  'HoriProInternational': 1,
#  'Cloud22': 1,
#  'Directions': 1,
#  'Code': 1,
#  'TrickBlock': 1,
#  'Delightworks': 1,
#  'TatsunokoProduction': 1,
#  'Imagica': 1}

# %%
# Ordena o resultado
{k: v for k, v in sorted(prod_dic.items(), key = lambda item: item[1])}
# Out:
# {'StudioMoriken': 1,
#  'MiracleBus': 1,
#  'Quaras': 1,
#  'SoundTeamDonJuan': 1,
#  'Amuse': 1,
#  'BeDream': 1,
#  'dugout': 1,
#  'Sumzap': 1,
#  'Annapuru': 1,
#  'Takeshobo': 1,
#  'SKYPerfectWellThink': 1,
#  'ScienceSARU': 1,
#  'TAP': 1,
#  'Madhouse': 1,
#  'HiroshimaTelevision': 1,
#  'CA-CygamesAnimeFund': 1,
#  'NewGin': 1,
#  'Sega': 1,
#  'MadBox': 1,
#  'Sonilude': 1,
#  'RexEntertainment': 1,
#  'BarnumStudio': 1,
#  'TCEntertainment': 1,
#  'NipponTelevisionMusic': 1,
#  'FBC': 1,
#  'SpaceyMusicEntertainment': 1,
#  'HeartCompany': 1,
#  'TrilogyFutureStudio': 1,
#  'Shout!Factory': 1,
#  'YomiuriShimbun': 1,
#  'MediaLinkEntertainmentLimited': 1,
#  'Bitgrooovepromotion': 1,
#  'NAZ': 1,
#  'ReddogCultureHouse': 1,
#  'Sunrise': 1,
#  'StudioRFInc.': 1,
#  'ShounenGahousha': 1,
#  'ForecastCommunications': 1,
#  'EggFirm': 1,
#  'GREE': 1,
#  'OLM': 1,
#  'VoyagerEntertainment': 1,
#  'Shinshokan': 1,
#  'D.N.DreamPartners': 1,
#  'STORY': 1,
#  'LawsonEntertainment': 1,
#  'Gainax': 1,
#  'C-one': 1,
#  'Infinite': 1,
#  'ADKMarketingSolutions': 1,
#  'StudioWombat': 1,
#  'SMEVisualWorks': 1,
#  'Arquebuse': 1,
#  'StudioFantasia': 1,
#  'FuRyu': 1,
#  'AsahiBroadcasting': 1,
#  'AbeShuujiJimusho': 1,
#  'ShizuokaAsahiTelevision': 1,
#  'KadokawaAnimation': 1,
#  'KinoshitaGroupHoldings': 1,
#  'BMGJapan': 1,
#  'KidsStation': 1,
#  'Sammy': 1,
#  'AnimatsuEntertainment': 1,
#  'KSS': 1,
#  'comico': 1,
#  'MyTheaterD.D.': 1,
#  'Mirai-Kojo': 1,
#  'Animatic': 1,
#  'Yahoo!Japan': 1,
#  'RialtoEntertainment': 1,
#  'SonyPCL': 1,
#  'Shelty': 1,
#  'AmberFilmWorks': 1,
#  'IWill': 1,
#  'Kinyosha': 1,
#  'Shinchosha': 1,
#  'Graphinica': 1,
#  'FrontLine': 1,
#  'AiAddiction': 1,
#  'A-Sketch': 1,
#  'Akatsuki': 1,
#  'TMS-Kyokuchi': 1,
#  'GDH': 1,
#  'SotsuMusicPublishing': 1,
#  'WarnerMusicJapan': 1,
#  'MAGNET': 1,
#  'EMI': 1,
#  'YomiuriAdvertising': 1,
#  'TokyoAnimatorGakuin': 1,
#  'TOBooks': 1,
#  'JTBNextCreation': 1,
#  'Echoes': 1,
#  'GANSIS': 1,
#  'KBS': 1,
#  'DMM.com': 1,
#  'AkitaShoten': 1,
#  'RobotCommunications': 1,
#  'AgeGlobalNetworks': 1,
#  'CBCTelevision': 1,
#  'VisualArts': 1,
#  'MyricaMusic': 1,
#  'DreamForce': 1,
#  'RAY': 1,
#  'Pia': 1,
#  'TokyoMovieShinsha': 1,
#  'WaltDisneyStudios': 1,
#  'J.C.Staff': 1,
#  'NTTDocomo': 1,
#  'BandaiChannel': 1,
#  'USEN': 1,
#  'LucentPicturesEntertainment': 1,
#  'PioneerLDC': 1,
#  'SonyPicturesEntertainment': 1,
#  '5pb.': 1,
#  'HoriProInternational': 1,
#  'Cloud22': 1,
#  'Directions': 1,
#  'Code': 1,
#  'TrickBlock': 1,
#  'Delightworks': 1,
#  'TatsunokoProduction': 1,
#  'Imagica': 1,
#  'StudioJack': 2,
#  'TokumaJapanCommunications': 2,
#  'AudioHighs': 2,
#  'voqueting': 2,
#  'CycloneGraphics': 2,
#  'KanetsuInvestment': 2,
#  'GlobalSolutions': 2,
#  'd-rights': 2,
#  'Konami': 2,
#  'AshiProduction': 2,
#  'MedicosEntertainment': 2,
#  'Seikaisha': 2,
#  'CrunchyrollSCAnimeFund': 2,
#  'ToeiAnimation': 2,
#  'KansaiTelecasting': 2,
#  'DearStageinc.': 2,
#  'SharefunStudio': 2,
#  'AHAEntertainment': 2,
#  'KamikazeDouga': 2,
#  'SonyMusicSolutions': 2,
#  'LawsonHMVEntertainment': 2,
#  'Imagine': 2,
#  'MicroMagazinePublishing': 2,
#  'chara-ani.com': 2,
#  'Toranoana': 2,
#  'MarvelousAQL': 2,
#  'BandaiNamcoLiveCreative': 2,
#  'Glovision': 2,
#  'BeyondC.': 2,
#  'Bushiroad': 2,
#  'SogoVision': 2,
#  'Nichion': 2,
#  'GoodSmileFilm': 2,
#  'MediaNet': 2,
#  'Sumitomo': 2,
#  'UltraSuperPictures': 2,
#  'TVOsaka': 3,
#  'MiracleRobo': 3,
#  'bilibili': 3,
#  'KingRecords': 3,
#  'NagoyaBroadcastingNetwork': 3,
#  'DocomoAnimeStore': 3,
#  'AudioTanaka': 3,
#  'DeNA': 3,
#  'StudioHibari': 3,
#  'MagGarden': 3,
#  'YomikoAdvertising': 3,
#  'Q-Tec': 3,
#  'GYAO!': 3,
#  'TohoMusic': 3,
#  'Imagin': 3,
#  'OBPlanning': 3,
#  '81Produce': 3,
#  'TokumaJapan': 3,
#  'TechnoSound': 4,
#  'TrinitySound': 4,
#  'KittyFilms': 4,
#  'TwinEngine': 4,
#  'IRMALADOUCE': 4,
#  'AvexEntertainment': 4,
#  'StarchildRecords': 4,
#  'MAGES.': 4,
#  'AsatsuDK': 4,
#  'Banpresto': 4,
#  'NHKEnterprises': 4,
#  'HappinetPictures': 4,
#  'BandaiNamcoGames': 4,
#  'Lawson': 4,
#  'ASCIIMediaWorks': 4,
#  'YomiuriTVEnterprise': 4,
#  'TMSEntertainment': 4,
#  'TMSMusic': 5,
#  'BandaiNamcoEntertainment': 5,
#  'Cygames': 5,
#  'TokyoMX': 5,
#  'SakuraCreate': 5,
#  'BandaiSpirits': 5,
#  'YTV': 5,
#  'Houbunsha': 5,
#  'NipponColumbia': 5,
#  'Happinet': 5,
#  'KadokawaPicturesJapan': 6,
#  '"ToysFactory"': 6,
#  'ABCAnimation': 6,
#  'HakuhodoDYMediaPartners': 6,
#  'BSFuji': 6,
#  'TencentPenguinPictures': 6,
#  'Marvelous': 6,
#  'HalfH.PStudio': 6,
#  'FujipacificMusic': 6,
#  'TVTokyoMusic': 6,
#  'Animax': 6,
#  'GoodSmileCompany': 6,
#  'NBCUniversalEntertainmentJapan': 6,
#  'Showgate': 6,
#  'GeneonUniversalEntertainment': 6,
#  'PonyCanyonEnterprise': 7,
#  'TBS': 7,
#  'AnimationDo': 7,
#  'DelfiSound': 7,
#  'SonyMusicCommunications': 7,
#  'YomiuriTelecasting': 7,
#  'TohokushinshaFilmCorporation': 7,
#  'VictorEntertainment': 7,
#  'TVAsahi': 7,
#  'WOWOW': 7,
#  'Memory-Tech': 7,
#  'BandaiNamcoArts': 7,
#  'AvexPictures': 8,
#  'AsmikAce': 8,
#  'JREastMarketing&Communications': 8,
#  'KyorakuIndustrialHoldings': 8,
#  'flyingDOG': 8,
#  'SquareEnix': 9,
#  'Nitroplus': 9,
#  'Shogakukan-ShueishaProductions': 9,
#  'MagicCapsule': 9,
#  'HakuhodoDYMusic&Pictures': 10,
#  'KadokawaMediaHouse': 10,
#  'Genco': 10,
#  'FrontierWorks': 11,
#  'TokumaShoten': 11,
#  'Rakuonsha': 11,
#  'MediaFactory': 12,
#  'DAXProduction': 12,
#  'Notes': 12,
#  'BS11': 12,
#  'ProductionI.G': 13,
#  'Sotsu': 14,
#  'Hakusensha': 15,
#  'NihonAdSystems': 16,
#  'Shochiku': 16,
#  'WarnerBros.Japan': 17,
#  'AT-X': 18,
#  'TOHOanimation': 18,
#  'Shogakukan': 20,
#  'KadokawaShoten': 20,
#  'Toho': 21,
#  'VAP': 22,
#  'NHK': 24,
#  'KlockWorx': 24,
#  'SonyMusicEntertainment': 25,
#  'BandaiVisual': 27,
#  'PonyCanyon': 29,
#  'NipponTelevisionNetwork': 29,
#  'Lantis': 29,
#  'FujiTV': 40,
#  'Bandai': 44,
#  'MainichiBroadcastingSystem': 48,
#  'Movic': 48,
#  'Kadokawa': 51,
#  'Kodansha': 52,
#  'TVTokyo': 53,
#  'Shueisha': 68,
#  'Dentsu': 70,
#  'Aniplex': 100}

# %%
prod_dic["Aniplex"]
# Out:
# 100

# %%
prod_dic["Dentsu"]
# Out:
# 70

# %%
prod_dic["Shueisha"]
# Out:
# 68

# %% [markdown]
# Aniplex, Dentsu e Shueisha são os produtores mais populares.

# %% [markdown]
# ## 10- Considerando o produtor que mais participou da produção de animes, qual a média de score, popularidade e membros?

# %%
# Remove os valores NA
df2 = df.dropna(subset = ['producers'])

# %%
# Filtra pelo producer e gera um novo dataframe
df3 = df2[df2["producers"].str.contains("Aniplex")]

# %%
df3.head()
# Out:
#     ranking                              name  \
# 0       1.0  Fullmetal Alchemist: Brotherhood
# 1       2.0                          Gintama°
# 5       6.0                          Gintama'
# 8       9.0               Gintama': Enchousen
# 10     11.0                          Gintama.
#
#                                             producers  votersCount  score  \
# 0   Aniplex;SquareEnix;MainichiBroadcastingSystem;...    1650275.0   9.15
# 1                              TVTokyo;Aniplex;Dentsu     173906.0   9.09
# 5   TVTokyo;Aniplex;Dentsu;TrinitySound;MiracleRob...     181741.0   9.06
# 8          TVTokyo;Aniplex;Dentsu;Shueisha;MiracleBus     132344.0   9.04
# 10                    TVTokyo;Aniplex;Dentsu;Shueisha     111480.0   8.98
#
#     popularity    members  favorite  episodes animeType premiredDate  \
# 0          3.0  2713695.0  191501.0      64.0        TV  Spring 2009
# 1        337.0   493336.0   13063.0      51.0        TV  Spring 2015
# 5        381.0   435755.0    6532.0      51.0        TV  Spring 2011
# 8        690.0   264816.0    2615.0      13.0        TV    Fall 2012
# 10       726.0   250362.0    2370.0      12.0        TV  Winter 2017
#
#    animeSource                                 genres                studios  \
# 0        Manga  Action;Adventure;Comedy;Drama;Fantasy                  Bones
# 1        Manga                   Action;Comedy;Sci-fi  Bandai Namco Pictures
# 5        Manga                   Action;Comedy;Sci-fi                Sunrise
# 8        Manga                   Action;Comedy;Sci-fi                Sunrise
# 10       Manga                   Action;Comedy;Sci-fi  Bandai Namco Pictures
#
#                        licenses       rating  \
# 0   Funimation;AniplexofAmerica        R-17+
# 1        Funimation;Crunchyroll  PG-13-Teens
# 5                           NaN  PG-13-Teens
# 8                           NaN  PG-13-Teens
# 10                          NaN  PG-13-Teens
#
#                                              Japanese  \
# 0   Kugimiya,Rie;Park,Romi;Utsumi,Kenji;Utsumi,Ken...
# 1   Kugimiya,Rie;Ishii,Kouji;Sugita,Tomokazu;Tomat...
# 5   Kugimiya,Rie;Sugita,Tomokazu;Sakaguchi,Daisuke...
# 8   Kugimiya,Rie;Sugita,Tomokazu;Sakaguchi,Daisuke...
# 10  Kugimiya,Rie;Ishida,Akira;Kaida,Yuki;Sugita,To...
#
#                                               Italian  \
# 0   Ponticelli,Benedetta;Novara,Renato;Scianca,Pat...
# 1                                                 NaN
# 5                                                 NaN
# 8                                                 NaN
# 10                                                NaN
#
#                                        Portuguese(BR)  \
# 0   Andreatto,Rodrigo;Campos,Marcelo;Zink,Mariana;...
# 1                                                 NaN
# 5                                                 NaN
# 8                                                 NaN
# 10                                                NaN
#
#                                                German  \
# 0   Gerick,Wanja;Turba,David;Häcke,Maximiliane;Mai...
# 1                                                 NaN
# 5                                                 NaN
# 8                                                 NaN
# 10                                                NaN
#
#                                             Hungarian  \
# 0   Baráth,István;Szabó,Máté;Faragó,András;Varga,R...
# 1                                                 NaN
# 5                                                 NaN
# 8                                                 NaN
# 10                                                NaN
#
#                                               English  \
# 0   Whitehead,Maxey;Truncale,Lily;Mignogna,Vic;Hof...
# 1   Loewen,Jocelyne;Daingerfield,Michael;Pitre,Sab...
# 5                                                 NaN
# 8                                                 NaN
# 10                                                NaN
#
#                                                Korean  \
# 0   Yun,MiNa;O,InSeong;Yang,JeongHwa;Lee,JiYeong;H...
# 1                                                 NaN
# 5                                                 NaN
# 8                                                 NaN
# 10                                                NaN
#
#                                               Spanish  \
# 0   Torres,Jhonny;Vieira,JoseManuel;Perez,LuisMigu...
# 1                                                 NaN
# 5                                                 NaN
# 8                                                 NaN
# 10                                                NaN
#
#                                                French Mandarin Hebrew  \
# 0   Pic,Audrey;Boudonnat,Lucille;Pestel,Arthur;Cre...      NaN    NaN
# 1                                                 NaN      NaN    NaN
# 5                                                 NaN      NaN    NaN
# 8                                                 NaN      NaN    NaN
# 10                                                NaN      NaN    NaN
#
#                       Producer                         Director  \
# 0   Cook,Justin;Yonai,Noritomo                    Irie,Yasuhiro
# 1                          NaN  Fujita,Youichi;Miyawaki,Chizuru
# 5                          NaN                   Fujita,Youichi
# 8                          NaN                   Fujita,Youichi
# 10                         NaN  Fujita,Youichi;Miyawaki,Chizuru
#
#                                       EpisodeDirector  \
# 0   Irie,Yasuhiro;Ikehata,Hiroshi;Ikezoe,Takahiro;...
# 1   Asami,Matsuo;Koshida,Tomoaki;Minami,Yasuhiro;M...
# 5   Fujita,Youichi;Minami,Yasuhiro;Miyawaki,Chizur...
# 8                     Fujita,Youichi;Miyawaki,Chizuru
# 10                                    Minami,Yasuhiro
#
#                                            Storyboard  \
# 0   Irie,Yasuhiro;Ikezoe,Takahiro;Kinutani,Soushi;...
# 1     Fujita,Youichi;Miyawaki,Chizuru;Minami,Yasuhiro
# 5   Fujita,Youichi;Minami,Yasuhiro;Miyawaki,Chizur...
# 8                     Fujita,Youichi;Miyawaki,Chizuru
# 10                                    Minami,Yasuhiro
#
#                             SoundDirector  \
# 0                           Mima,Masafumi
# 1                        Takamatsu,Shinji
# 5                    Kobayashi,Katsuyoshi
# 8                                     NaN
# 10  Kobayashi,Katsuyoshi;Takamatsu,Shinji
#
#                                          KeyAnimation  \
# 0   Ikezoe,Takahiro;Kinutani,Soushi;Morii,Kenshiro...
# 1   Miyawaki,Chizuru;Abe,Miyuki;Hayashi,Kanako;Hay...
# 5   Miyawaki,Chizuru;Abe,Shingo;Habe,Takashi;Haseg...
# 8   Inada,Toshiko;Murata,Noriyasu;Saitou,Kazuya;Sa...
# 10       Ishikawa,Mariko;Itou,Tatsufumi;Sasaki,Youhei
#
#                                       2ndKeyAnimation  \
# 0   Ikezoe,Takahiro;Akasaka,Shunji;Kameda,Yoshimic...
# 1      Hayashi,Kanako;Honjou,Keiichirou;Sasaki,Youhei
# 5   Miyawaki,Chizuru;Matsuyama,Kouji;Taniguchi,Yos...
# 8                                                 NaN
# 10                                                NaN
#
#                  CharacterDesign  \
# 0   Morii,Kenshirou;Kanno,Hiroki
# 1                Takeuchi,Shinji
# 5                Takeuchi,Shinji
# 8                Takeuchi,Shinji
# 10               Takeuchi,Shinji
#
#                                                Script  SeriesComposition  \
# 0   Burgmeier,John;Minakami,Seishi;Oonogi,Hiroshi;...     Oonogi,Hiroshi
# 1          Kishimoto,Taku;Matsubara,Shuu;Mieno,Hitomi                NaN
# 5    Shimoyama,Kento;Yamatoya,Akatsuki;Yokote,Michiko  Yamatoya,Akatsuki
# 8    Shimoyama,Kento;Yamatoya,Akatsuki;Yokote,Michiko  Yamatoya,Akatsuki
# 10                                                NaN                NaN
#
#                                       ThemeSongLyrics  \
# 0   CHEMISTRY;NICOTouchestheWalls;SCANDAL;SID;Suki...
# 1               AquaTimez;BLUEENCOUNT;DOES;HoneyWorks
# 5                             Prague;SPYAIR;ecosystem
# 8                                              SPYAIR
# 10                                                NaN
#
#                                  ThemeSongPerformance  \
# 0   CHEMISTRY;Fukuhara,Miho;["LilB";NICOTouchesthe...
# 1   AquaTimez;BLUEENCOUNT;CHiCO;DOES;HoneyWorks;Ne...
# 5          FLiP;Prague;SPYAIR;ecosystem;serialTVdrama
# 8                     AMOYAMO;SPYAIR;Takahashi,Mikako
# 10                                         CHiCO;ЯeaL
#
#                                  ThemeSongArrangement  \
# 0   Kameda,Seiji;NICOTouchestheWalls;SID;SukimaSwitch
# 1         AquaTimez;BLUEENCOUNT;DOES;HoneyWorks;Swimy
# 5                             Prague;SPYAIR;ecosystem
# 8                                              SPYAIR
# 10                                                NaN
#
#                         ThemeSongComposition  \
# 0   NICOTouchestheWalls;SID;SukimaSwitch;Yui
# 1      AquaTimez;BLUEENCOUNT;DOES;HoneyWorks
# 5                    Prague;SPYAIR;ecosystem
# 8                                     SPYAIR
# 10                                HoneyWorks
#
#                                     AnimationDirector  OriginalCreator  \
# 0   Aono,Atsushi;Iijima,Hiroya;Ishino,Satoshi;Koba...   Arakawa,Hiromu
# 1   Honjou,Keiichirou;Ikeuchi,Naoko;Ishikawa,Marik...  Sorachi,Hideaki
# 5   Hisayuki,Hirokazu;Honjou,Keiichirou;Ishikawa,M...  Sorachi,Hideaki
# 8                         Sasaki,Youhei;Suzuki,Hiromi  Sorachi,Hideaki
# 10                        Nakamura,Yumi;Sasaki,Youhei  Sorachi,Hideaki
#
#                                           ADRDirector ExecutiveProducer  \
# 0   Bezerra,Úrsula;Campos,Marcelo;Glass,Caitlin;Ka...      Fukunaga,Gen
# 1                                                 NaN               NaN
# 5                                                 NaN               NaN
# 8                                                 NaN               NaN
# 10                                                NaN               NaN
#
#                              ChiefAnimationDirector DirectorofPhotography  \
# 0   Fukuoka,Hidenori;Kameda,Yoshimichi;Kaneda,Naomi       Furumoto,Mayuko
# 1                                               NaN        Teramoto,Yuuki
# 5                                               NaN                   NaN
# 8                                               NaN                   NaN
# 10                                  Takeuchi,Shinji        Teramoto,Yuuki
#
#                                   In-BetweenAnimation  \
# 0   Kameda,Yoshimichi;Oosawa,Mina;Saitou,Kengo;Yok...
# 1                                                 NaN
# 5                                                 NaN
# 8                                                 NaN
# 10                                                NaN
#
#                                         BackgroundArt  \
# 0   Kanehira,Kazushige;Nakajima,Mika;Ooizumi,Anna;...
# 1                                                 NaN
# 5                                        Kanai,Shingo
# 8                       Nakajima,Yuichiro;Nuibe,Fumie
# 10                                                NaN
#
#                       Planning      ColorDesign  \
# 0   Minami,Masahiko;Ueda,Masuo     Nakao,Fusako
# 1               Fujita,Youichi  Utagawa,Ritsuko
# 5                          NaN  Utagawa,Ritsuko
# 8                          NaN  Utagawa,Ritsuko
# 10                         NaN  Utagawa,Ritsuko
#
#         AssistantAnimationDirector         Editing  \
# 0   Park,Seong-Hu;Yoshioka,Takeshi   Sadamatsu,Gou
# 1                    Nakamura,Yumi  Seyama,Takeshi
# 5                              NaN  Seyama,Takeshi
# 8                              NaN  Seyama,Takeshi
# 10                             NaN  Seyama,Takeshi
#
#                         ArtDirector        Music ProductionCoordination  \
# 0                     Satou,Takeshi  Senju,Akira             Shinya,Une
# 1   Fukushima,Takayoshi;Maniwa,Nami   AudioHighs                    NaN
# 5                               NaN   AudioHighs                    NaN
# 8                               NaN   AudioHighs                    NaN
# 10  Fukushima,Takayoshi;Maniwa,Nami   AudioHighs                    NaN
#
#      DigitalPaint     ColorSetting AssistantDirector SoundEffects  \
# 0   Uemura,Takako              NaN               NaN          NaN
# 1             NaN  Utagawa,Ritsuko               NaN          NaN
# 5             NaN  Utagawa,Ritsuko               NaN  Mutou,Akiko
# 8             NaN              NaN               NaN  Mutou,Akiko
# 10            NaN              NaN               NaN          NaN
#
#     InsertedSongPerformance OriginalCharacterDesign Setting Screenplay  \
# 0                       NaN                     NaN     NaN        NaN
# 1                       NaN                     NaN     NaN        NaN
# 5   Anri;Arai,Masahito;DOES                     NaN     NaN        NaN
# 8                       NaN                     NaN     NaN        NaN
# 10                      NaN                     NaN     NaN        NaN
#
#    AssociateProducer SpecialEffects AnimationCheck ProductionAssistant  \
# 0                NaN            NaN            NaN                 NaN
# 1                NaN            NaN            NaN                 NaN
# 5                NaN            NaN            NaN                 NaN
# 8                NaN            NaN            NaN                 NaN
# 10               NaN            NaN  Sasaki,Youhei                 NaN
#
#          SoundSupervisor PrincipleDrawing AssistantProducer ProductionManager  \
# 0                    NaN              NaN               NaN               NaN
# 1                    NaN              NaN               NaN               NaN
# 5                    NaN              NaN               NaN               NaN
# 8                    NaN              NaN               NaN               NaN
# 10  Kobayashi,Katsuyoshi              NaN               NaN               NaN
#
#    SoundManager Co-Director SeriesProductionDirector MechanicalDesign  \
# 0           NaN         NaN                      NaN              NaN
# 1           NaN         NaN                      NaN              NaN
# 5           NaN         NaN                      NaN              NaN
# 8           NaN         NaN                      NaN              NaN
# 10          NaN         NaN                      NaN              NaN
#
#    PlanningProducer Layout ChiefProducer Recording DialogueEditing  \
# 0               NaN    NaN           NaN       NaN             NaN
# 1               NaN    NaN           NaN       NaN             NaN
# 5               NaN    NaN           NaN       NaN             NaN
# 8               NaN    NaN           NaN       NaN             NaN
# 10              NaN    NaN           NaN       NaN             NaN
#
#    RecordingEngineer Creator RecordingAssistant Publicity Co-Producer  \
# 0                NaN     NaN                NaN       NaN         NaN
# 1                NaN     NaN                NaN       NaN         NaN
# 5                NaN     NaN                NaN       NaN         NaN
# 8                NaN     NaN                NaN       NaN         NaN
# 10               NaN     NaN                NaN       NaN         NaN
#
#    CastingDirector Re-RecordingMixing AssistantProductionCoordinat  \
# 0              NaN                NaN                          NaN
# 1              NaN                NaN                          NaN
# 5              NaN                NaN                          NaN
# 8              NaN                NaN                          NaN
# 10             NaN                NaN                          NaN
#
#    SettingManager
# 0             NaN
# 1             NaN
# 5             NaN
# 8             NaN
# 10            NaN

# %%
df3.shape
# Out:
# (100, 90)

# %%
df3['score'].mean()
# Out:
# 8.461900000000004

# %%
df3['popularity'].mean()
# Out:
# 672.04

# %%
df3['members'].mean()
# Out:
# 575046.02

# %% [markdown]
# Agora é com você. Que outras análises poderiam ser feitas nesse conjunto de dados?

# %% [markdown]
# # Fim
